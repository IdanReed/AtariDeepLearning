# %%
from pathlib import Path
from npz_loader import discover_game_npz_paths, get_sequences_by_game, fix_obs_paths
from atari_preprocess import preprocess_one_sequence, find_image_folders
from torch.utils.data import Dataset, DataLoader



# 1. GAME ROOT DIRECTORY (Pick any game)
train_game_dirs = [
    Path("dataset/BeamRiderNoFrameskip-v4/BeamRiderNoFrameskip-v4")
    #Path("dataset/MsPacmanNoFrameskip-v4/BeamRiderNoFrameskip-v4"),
    #Path("dataset/BreakoutNoFrameskip-v4/BreakoutNoFrameskip-v4"),
    #Path("dataset/MsPacmanNoFrameskip-v4/EnduroNoFrameskip-v4"),
    #Path("dataset/BreakoutNoFrameskip-v4/MsPacmanNoFrameskip-v4"),
    #Path("dataset/MsPacmanNoFrameskip-v4/QbertNoFrameskip-v4"),
    #Path("dataset/BreakoutNoFrameskip-v4/SeaquestNoFrameskip-v4"),
    #Path("dataset/BreakoutNoFrameskip-v4/SpaceInvadersNoFrameskip-v4"),
]
game_tokens = []
for game_root in train_game_dirs:

    # 2. Load ALL NPZ files (already sorted by discover_game_npz_paths)
    npz_paths_by_game = discover_game_npz_paths([game_root])
    game_to_sequences = get_sequences_by_game(npz_paths_by_game)
    sequences_by_game = fix_obs_paths(game_to_sequences, dataset_root="dataset")

    game_key = list(sequences_by_game.keys())[0]
    npz_sequences = sequences_by_game[game_key]

    print(f"Found {len(npz_sequences)} NPZ sequences.")

    # 3. Load ALL image folders for this game
    image_folders = find_image_folders(game_root)
    print(f"Found {len(image_folders)} image folders.")

    if len(image_folders) != len(npz_sequences):
        print("WARNING: NPZ count and image folder count differ!")
        print("Index pairing may need manual correction!")

    # 4. Preprocess ALL sequences into token lists
    all_token_lists = []

    for idx, npz_seq in enumerate(npz_sequences):
        img_folder = image_folders[idx]
        print(f"\nProcessing episode {idx}/{len(npz_sequences)-1}")
        print(f"NPZ ↔ {img_folder.name}")

        tokens = preprocess_one_sequence(
            npz_seq=npz_seq,
            game_root=game_root,
            seq_index=idx    # episode index
        )

        print(f" → Tokens created: {len(tokens)}")

        all_token_lists.append(tokens)

    print("\n======== PREPROCESSING COMPLETE ========")
    print(f"Total episodes processed: {len(all_token_lists)}")
    print(f"Example episode #0 token count: {len(all_token_lists[0])}")
    game_tokens.append(all_token_lists)
# Out:
# Found 200 NPZ sequences.
# Found 200 image folders.
#
# Processing episode 0/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-0
#  → Tokens created: 21372
#
# Processing episode 1/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-1
#  → Tokens created: 14274
#
# Processing episode 2/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-2
#  → Tokens created: 21021
#
# Processing episode 3/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-3
#  → Tokens created: 17043
#
# Processing episode 4/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-4
#  → Tokens created: 20787
#
# Processing episode 5/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-5
#  → Tokens created: 18837
#
# Processing episode 6/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-6
#  → Tokens created: 20124
#
# Processing episode 7/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-7
#  → Tokens created: 32643
#
# Processing episode 8/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-8
#  → Tokens created: 18954
#
# Processing episode 9/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-9
#  → Tokens created: 22737
#
# Processing episode 10/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-10
#  → Tokens created: 36738
#
# Processing episode 11/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-11
#  → Tokens created: 21606
#
# Processing episode 12/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-12
#  → Tokens created: 21606
#
# Processing episode 13/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-13
#  → Tokens created: 14235
#
# Processing episode 14/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-14
#  → Tokens created: 17628
#
# Processing episode 15/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-15
#  → Tokens created: 17277
#
# Processing episode 16/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-16
#  → Tokens created: 27690
#
# Processing episode 17/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-17
#  → Tokens created: 18798
#
# Processing episode 18/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-18
#  → Tokens created: 18837
#
# Processing episode 19/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-19
#  → Tokens created: 22152
#
# Processing episode 20/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-20
#  → Tokens created: 28041
#
# Processing episode 21/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-21
#  → Tokens created: 20904
#
# Processing episode 22/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-22
#  → Tokens created: 20436
#
# Processing episode 23/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-23
#  → Tokens created: 14391
#
# Processing episode 24/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-24
#  → Tokens created: 16575
#
# Processing episode 25/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-25
#  → Tokens created: 34320
#
# Processing episode 26/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-26
#  → Tokens created: 28782
#
# Processing episode 27/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-27
#  → Tokens created: 15912
#
# Processing episode 28/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-28
#  → Tokens created: 15912
#
# Processing episode 29/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-29
#  → Tokens created: 21918
#
# Processing episode 30/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-30
#  → Tokens created: 17862
#
# Processing episode 31/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-31
#  → Tokens created: 15756
#
# Processing episode 32/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-32
#  → Tokens created: 17589
#
# Processing episode 33/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-33
#  → Tokens created: 35763
#
# Processing episode 34/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-34
#  → Tokens created: 21567
#
# Processing episode 35/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-35
#  → Tokens created: 32799
#
# Processing episode 36/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-36
#  → Tokens created: 16692
#
# Processing episode 37/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-37
#  → Tokens created: 21684
#
# Processing episode 38/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-38
#  → Tokens created: 17316
#
# Processing episode 39/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-39
#  → Tokens created: 27183
#
# Processing episode 40/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-40
#  → Tokens created: 18798
#
# Processing episode 41/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-41
#  → Tokens created: 40482
#
# Processing episode 42/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-42
#  → Tokens created: 25779
#
# Processing episode 43/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-43
#  → Tokens created: 18135
#
# Processing episode 44/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-44
#  → Tokens created: 14781
#
# Processing episode 45/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-45
#  → Tokens created: 29718
#
# Processing episode 46/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-46
#  → Tokens created: 20904
#
# Processing episode 47/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-47
#  → Tokens created: 21684
#
# Processing episode 48/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-48
#  → Tokens created: 15756
#
# Processing episode 49/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-49
#  → Tokens created: 12051
#
# Processing episode 50/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-50
#  → Tokens created: 12441
#
# Processing episode 51/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-51
#  → Tokens created: 29835
#
# Processing episode 52/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-52
#  → Tokens created: 26052
#
# Processing episode 53/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-53
#  → Tokens created: 19656
#
# Processing episode 54/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-54
#  → Tokens created: 17121
#
# Processing episode 55/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-55
#  → Tokens created: 23049
#
# Processing episode 56/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-56
#  → Tokens created: 18486
#
# Processing episode 57/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-57
#  → Tokens created: 27222
#
# Processing episode 58/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-58
#  → Tokens created: 18096
#
# Processing episode 59/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-59
#  → Tokens created: 15756
#
# Processing episode 60/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-60
#  → Tokens created: 17901
#
# Processing episode 61/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-61
#  → Tokens created: 26169
#
# Processing episode 62/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-62
#  → Tokens created: 24063
#
# Processing episode 63/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-63
#  → Tokens created: 13728
#
# Processing episode 64/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-64
#  → Tokens created: 22698
#
# Processing episode 65/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-65
#  → Tokens created: 12441
#
# Processing episode 66/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-66
#  → Tokens created: 20319
#
# Processing episode 67/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-67
#  → Tokens created: 21996
#
# Processing episode 68/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-68
#  → Tokens created: 17628
#
# Processing episode 69/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-69
#  → Tokens created: 23127
#
# Processing episode 70/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-70
#  → Tokens created: 14898
#
# Processing episode 71/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-71
#  → Tokens created: 20397
#
# Processing episode 72/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-72
#  → Tokens created: 17901
#
# Processing episode 73/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-73
#  → Tokens created: 16614
#
# Processing episode 74/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-74
#  → Tokens created: 26364
#
# Processing episode 75/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-75
#  → Tokens created: 13728
#
# Processing episode 76/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-76
#  → Tokens created: 17004
#
# Processing episode 77/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-77
#  → Tokens created: 16614
#
# Processing episode 78/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-78
#  → Tokens created: 22113
#
# Processing episode 79/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-79
#  → Tokens created: 66768
#
# Processing episode 80/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-80
#  → Tokens created: 20670
#
# Processing episode 81/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-81
#  → Tokens created: 21372
#
# Processing episode 82/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-82
#  → Tokens created: 18798
#
# Processing episode 83/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-83
#  → Tokens created: 26949
#
# Processing episode 84/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-84
#  → Tokens created: 28431
#
# Processing episode 85/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-85
#  → Tokens created: 11583
#
# Processing episode 86/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-86
#  → Tokens created: 27378
#
# Processing episode 87/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-87
#  → Tokens created: 31044
#
# Processing episode 88/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-88
#  → Tokens created: 12051
#
# Processing episode 89/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-89
#  → Tokens created: 25545
#
# Processing episode 90/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-90
#  → Tokens created: 19812
#
# Processing episode 91/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-91
#  → Tokens created: 21684
#
# Processing episode 92/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-92
#  → Tokens created: 24297
#
# Processing episode 93/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-93
#  → Tokens created: 20085
#
# Processing episode 94/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-94
#  → Tokens created: 13143
#
# Processing episode 95/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-95
#  → Tokens created: 31005
#
# Processing episode 96/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-96
#  → Tokens created: 14235
#
# Processing episode 97/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-97
#  → Tokens created: 17784
#
# Processing episode 98/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-98
#  → Tokens created: 15834
#
# Processing episode 99/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-99
#  → Tokens created: 21528
#
# Processing episode 100/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-100
#  → Tokens created: 22074
#
# Processing episode 101/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-101
#  → Tokens created: 17784
#
# Processing episode 102/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-102
#  → Tokens created: 21684
#
# Processing episode 103/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-103
#  → Tokens created: 21021
#
# Processing episode 104/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-104
#  → Tokens created: 24297
#
# Processing episode 105/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-105
#  → Tokens created: 39507
#
# Processing episode 106/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-106
#  → Tokens created: 31551
#
# Processing episode 107/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-107
#  → Tokens created: 28587
#
# Processing episode 108/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-108
#  → Tokens created: 18915
#
# Processing episode 109/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-109
#  → Tokens created: 22464
#
# Processing episode 110/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-110
#  → Tokens created: 19578
#
# Processing episode 111/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-111
#  → Tokens created: 37986
#
# Processing episode 112/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-112
#  → Tokens created: 38376
#
# Processing episode 113/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-113
#  → Tokens created: 17862
#
# Processing episode 114/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-114
#  → Tokens created: 31551
#
# Processing episode 115/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-115
#  → Tokens created: 21528
#
# Processing episode 116/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-116
#  → Tokens created: 17862
#
# Processing episode 117/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-117
#  → Tokens created: 28431
#
# Processing episode 118/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-118
#  → Tokens created: 21372
#
# Processing episode 119/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-119
#  → Tokens created: 14274
#
# Processing episode 120/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-120
#  → Tokens created: 11583
#
# Processing episode 121/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-121
#  → Tokens created: 18486
#
# Processing episode 122/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-122
#  → Tokens created: 17628
#
# Processing episode 123/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-123
#  → Tokens created: 20904
#
# Processing episode 124/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-124
#  → Tokens created: 23517
#
# Processing episode 125/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-125
#  → Tokens created: 18798
#
# Processing episode 126/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-126
#  → Tokens created: 26364
#
# Processing episode 127/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-127
#  → Tokens created: 22659
#
# Processing episode 128/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-128
#  → Tokens created: 19578
#
# Processing episode 129/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-129
#  → Tokens created: 25779
#
# Processing episode 130/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-130
#  → Tokens created: 25428
#
# Processing episode 131/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-131
#  → Tokens created: 31395
#
# Processing episode 132/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-132
#  → Tokens created: 20046
#
# Processing episode 133/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-133
#  → Tokens created: 20787
#
# Processing episode 134/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-134
#  → Tokens created: 19656
#
# Processing episode 135/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-135
#  → Tokens created: 13143
#
# Processing episode 136/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-136
#  → Tokens created: 14898
#
# Processing episode 137/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-137
#  → Tokens created: 34281
#
# Processing episode 138/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-138
#  → Tokens created: 28041
#
# Processing episode 139/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-139
#  → Tokens created: 19578
#
# Processing episode 140/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-140
#  → Tokens created: 17628
#
# Processing episode 141/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-141
#  → Tokens created: 34788
#
# Processing episode 142/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-142
#  → Tokens created: 20670
#
# Processing episode 143/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-143
#  → Tokens created: 28392
#
# Processing episode 144/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-144
#  → Tokens created: 32799
#
# Processing episode 145/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-145
#  → Tokens created: 23127
#
# Processing episode 146/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-146
#  → Tokens created: 17316
#
# Processing episode 147/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-147
#  → Tokens created: 14235
#
# Processing episode 148/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-148
#  → Tokens created: 20124
#
# Processing episode 149/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-149
#  → Tokens created: 32643
#
# Processing episode 150/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-150
#  → Tokens created: 20826
#
# Processing episode 151/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-151
#  → Tokens created: 16575
#
# Processing episode 152/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-152
#  → Tokens created: 27183
#
# Processing episode 153/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-153
#  → Tokens created: 19578
#
# Processing episode 154/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-154
#  → Tokens created: 14235
#
# Processing episode 155/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-155
#  → Tokens created: 32331
#
# Processing episode 156/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-156
#  → Tokens created: 20358
#
# Processing episode 157/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-157
#  → Tokens created: 36543
#
# Processing episode 158/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-158
#  → Tokens created: 24336
#
# Processing episode 159/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-159
#  → Tokens created: 67431
#
# Processing episode 160/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-160
#  → Tokens created: 19305
#
# Processing episode 161/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-161
#  → Tokens created: 17277
#
# Processing episode 162/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-162
#  → Tokens created: 31239
#
# Processing episode 163/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-163
#  → Tokens created: 22464
#
# Processing episode 164/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-164
#  → Tokens created: 20241
#
# Processing episode 165/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-165
#  → Tokens created: 30576
#
# Processing episode 166/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-166
#  → Tokens created: 17823
#
# Processing episode 167/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-167
#  → Tokens created: 19305
#
# Processing episode 168/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-168
#  → Tokens created: 36699
#
# Processing episode 169/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-169
#  → Tokens created: 14391
#
# Processing episode 170/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-170
#  → Tokens created: 45513
#
# Processing episode 171/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-171
#  → Tokens created: 28041
#
# Processing episode 172/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-172
#  → Tokens created: 23439
#
# Processing episode 173/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-173
#  → Tokens created: 17277
#
# Processing episode 174/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-174
#  → Tokens created: 19305
#
# Processing episode 175/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-175
#  → Tokens created: 28431
#
# Processing episode 176/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-176
#  → Tokens created: 21060
#
# Processing episode 177/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-177
#  → Tokens created: 15756
#
# Processing episode 178/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-178
#  → Tokens created: 22152
#
# Processing episode 179/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-179
#  → Tokens created: 23127
#
# Processing episode 180/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-180
#  → Tokens created: 17043
#
# Processing episode 181/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-181
#  → Tokens created: 22464
#
# Processing episode 182/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-182
#  → Tokens created: 19032
#
# Processing episode 183/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-183
#  → Tokens created: 20904
#
# Processing episode 184/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-184
#  → Tokens created: 14781
#
# Processing episode 185/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-185
#  → Tokens created: 40482
#
# Processing episode 186/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-186
#  → Tokens created: 17862
#
# Processing episode 187/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-187
#  → Tokens created: 24648
#
# Processing episode 188/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-188
#  → Tokens created: 21567
#
# Processing episode 189/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-189
#  → Tokens created: 28041
#
# Processing episode 190/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-190
#  → Tokens created: 19305
#
# Processing episode 191/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-191
#  → Tokens created: 20436
#
# Processing episode 192/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-192
#  → Tokens created: 19149
#
# Processing episode 193/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-193
#  → Tokens created: 16692
#
# Processing episode 194/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-194
#  → Tokens created: 17823
#
# Processing episode 195/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-195
#  → Tokens created: 18837
#
# Processing episode 196/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-196
#  → Tokens created: 18837
#
# Processing episode 197/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-197
#  → Tokens created: 17277
#
# Processing episode 198/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-198
#  → Tokens created: 15951
#
# Processing episode 199/199
# NPZ ↔ BeamRiderNoFrameskip-v4-recorded_images-199
#  → Tokens created: 17823
#
# ======== PREPROCESSING COMPLETE ========
# Total episodes processed: 200
# Example episode #0 token count: 21372

# %%
import pickle
from pathlib import Path
from npz_loader import discover_game_npz_paths, get_sequences_by_game, fix_obs_paths
from atari_preprocess import preprocess_one_sequence, find_image_folders
import numpy as np

train_game_dirs = [
    Path("dataset/BeamRiderNoFrameskip-v4/BeamRiderNoFrameskip-v4"),
    #Path("dataset/BreakoutNoFrameskip-v4/BreakoutNoFrameskip-v4"),
    #Path("dataset/EnduroNoFrameskip-v4/EnduroNoFrameskip-v4"),
    #Path("dataset/MsPacmanNoFrameskip-v4/MsPacmanNoFrameskip-v4"),
    #Path("dataset/QbertNoFrameskip-v4/QbertNoFrameskip-v4"),
    #Path("dataset/SeaquestNoFrameskip-v4/SeaquestNoFrameskip-v4"),
    #Path("dataset/SpaceInvadersNoFrameskip-v4/SpaceInvadersNoFrameskip-v4"),
]

for game_root in train_game_dirs:

    # Load NPZ files
    npz_paths_by_game = discover_game_npz_paths([game_root])
    game_to_sequences = get_sequences_by_game(npz_paths_by_game)
    sequences_by_game = fix_obs_paths(game_to_sequences, dataset_root="dataset")

    game_key = list(sequences_by_game.keys())[0]
    npz_sequences = sequences_by_game[game_key]
    print(f"Found {len(npz_sequences)} NPZ sequences.")

    # Load image folders
    image_folders = find_image_folders(game_root)
    print(f"Found {len(image_folders)} image folders.")

    if len(image_folders) != len(npz_sequences):
        print("WARNING: NPZ count and image folder count differ!")
    # Preprocess & collect tokens for this game
    all_token_lists = []

    for idx, npz_seq in enumerate(npz_sequences):
        img_folder = image_folders[idx]
        print(f"\nProcessing episode {idx}/{len(npz_sequences)-1} — {img_folder.name}")

        tokens = preprocess_one_sequence(
            npz_seq=npz_seq,
            game_root=game_root,
            seq_index=idx
        )
        print(f" → Tokens created: {len(tokens)}")
        all_token_lists.append(tokens)

    print("\n======== PREPROCESSING COMPLETE ========")

    # Save tokens
    out_path = Path("token_outputs")
    out_path.mkdir(exist_ok=True)

    safe_game_key = str(game_key).replace("/", "_")   # <-- SIMPLE FIX

    pickle_file = out_path / f"{safe_game_key}_tokens.pkl"

    with open(pickle_file, "wb") as f:
        pickle.dump(all_token_lists, f)

    print(f"Saved token file → {pickle_file}")
    print("=====================================================\n")
# Out:
# Found 200 NPZ sequences.
# Found 200 image folders.
#
# Processing episode 0/199 — BeamRiderNoFrameskip-v4-recorded_images-0
#  → Tokens created: 3
#
# Processing episode 1/199 — BeamRiderNoFrameskip-v4-recorded_images-1
#  → Tokens created: 3
#
# Processing episode 2/199 — BeamRiderNoFrameskip-v4-recorded_images-2
#  → Tokens created: 3
#
# Processing episode 3/199 — BeamRiderNoFrameskip-v4-recorded_images-3
#  → Tokens created: 3
#
# Processing episode 4/199 — BeamRiderNoFrameskip-v4-recorded_images-4
#  → Tokens created: 3
#
# Processing episode 5/199 — BeamRiderNoFrameskip-v4-recorded_images-5
#  → Tokens created: 3
#
# Processing episode 6/199 — BeamRiderNoFrameskip-v4-recorded_images-6
#  → Tokens created: 3
#
# Processing episode 7/199 — BeamRiderNoFrameskip-v4-recorded_images-7
#  → Tokens created: 3
#
# Processing episode 8/199 — BeamRiderNoFrameskip-v4-recorded_images-8
#  → Tokens created: 3
#
# Processing episode 9/199 — BeamRiderNoFrameskip-v4-recorded_images-9
#  → Tokens created: 3
#
# Processing episode 10/199 — BeamRiderNoFrameskip-v4-recorded_images-10
#  → Tokens created: 3
#
# Processing episode 11/199 — BeamRiderNoFrameskip-v4-recorded_images-11
#  → Tokens created: 3
#
# Processing episode 12/199 — BeamRiderNoFrameskip-v4-recorded_images-12
#  → Tokens created: 3
#
# Processing episode 13/199 — BeamRiderNoFrameskip-v4-recorded_images-13
#  → Tokens created: 3
#
# Processing episode 14/199 — BeamRiderNoFrameskip-v4-recorded_images-14
#  → Tokens created: 3
#
# Processing episode 15/199 — BeamRiderNoFrameskip-v4-recorded_images-15
#  → Tokens created: 3
#
# Processing episode 16/199 — BeamRiderNoFrameskip-v4-recorded_images-16
#  → Tokens created: 3
#
# Processing episode 17/199 — BeamRiderNoFrameskip-v4-recorded_images-17
#  → Tokens created: 3
#
# Processing episode 18/199 — BeamRiderNoFrameskip-v4-recorded_images-18
#  → Tokens created: 3
#
# Processing episode 19/199 — BeamRiderNoFrameskip-v4-recorded_images-19
#  → Tokens created: 3
#
# Processing episode 20/199 — BeamRiderNoFrameskip-v4-recorded_images-20
#  → Tokens created: 3
#
# Processing episode 21/199 — BeamRiderNoFrameskip-v4-recorded_images-21
#  → Tokens created: 3
#
# Processing episode 22/199 — BeamRiderNoFrameskip-v4-recorded_images-22
#  → Tokens created: 3
#
# Processing episode 23/199 — BeamRiderNoFrameskip-v4-recorded_images-23
#  → Tokens created: 3
#
# Processing episode 24/199 — BeamRiderNoFrameskip-v4-recorded_images-24
#  → Tokens created: 3
#
# Processing episode 25/199 — BeamRiderNoFrameskip-v4-recorded_images-25
#  → Tokens created: 3
#
# Processing episode 26/199 — BeamRiderNoFrameskip-v4-recorded_images-26
#  → Tokens created: 3
#
# Processing episode 27/199 — BeamRiderNoFrameskip-v4-recorded_images-27
#  → Tokens created: 3
#
# Processing episode 28/199 — BeamRiderNoFrameskip-v4-recorded_images-28
#  → Tokens created: 3
#
# Processing episode 29/199 — BeamRiderNoFrameskip-v4-recorded_images-29
#  → Tokens created: 3
#
# Processing episode 30/199 — BeamRiderNoFrameskip-v4-recorded_images-30
#  → Tokens created: 3
#
# Processing episode 31/199 — BeamRiderNoFrameskip-v4-recorded_images-31
#  → Tokens created: 3
#
# Processing episode 32/199 — BeamRiderNoFrameskip-v4-recorded_images-32
#  → Tokens created: 3
#
# Processing episode 33/199 — BeamRiderNoFrameskip-v4-recorded_images-33

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from transformers.models.decision_transformer.modeling_decision_transformer import DecisionTransformerModel
from transformers.models.decision_transformer.configuration_decision_transformer import DecisionTransformerConfig
import torch
import EpisodeData
from torch.utils.data import Dataset, DataLoader
import random
import torch.optim as optim

IMG_SIZE = 84
PATCH_SIZE = 14
PATCHES_PER_FRAME = (IMG_SIZE // PATCH_SIZE) ** 2    # 36 patches
RETURN_MIN = -20
RETURN_MAX = 100
PATCH_EMB_SIZE = 128
NUM_EPOCHS = 10
CONTEXT_LENGTH = 20
BATCH_SIZE = 32


# Data Loading and Sampling
# all_token_lists[0] is an episode with states, actions, rewards-to-go


#Additional data preprocessing

dataset = EpisodeData.EpisodeData(all_token_lists, CONTEXT_LENGTH)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, drop_last=True)

# Initializing a DecisionTransformer configuration
configuration = DecisionTransformerConfig(state_dim=PATCHES_PER_FRAME * PATCH_EMB_SIZE, act_dim=18, max_length=CONTEXT_LENGTH, n_layer=3, n_head=1)
configuration.action_tanh = False

# Initializing a model (with random weights) from the configuration
model = DecisionTransformerModel(configuration)
print(model.embed_state)
print(model.embed_timestep)
print(model.embed_action)




# Forward pass need to standardize lengths for episode and mask the padded tokens
# Context Length = 20
# After padding, randomly select a subsequence of length 20 from each episode of the batch
optimizer = optim.Adam(model.parameters(), lr=1e-4)


for epoch in range(NUM_EPOCHS):
    model.train()
    total_loss = 0
    batch_idx = 1
    for state, action, rtg in dataloader:

        state = state.clone().detach().float()
        action = action.clone().detach().long()
        rtg = rtg.clone().detach().float()
        timesteps = torch.arange(CONTEXT_LENGTH).unsqueeze(0).repeat(state.size(0), 1)

        action = torch.nn.functional.one_hot(action, num_classes=18).float()
        rtg = rtg.unsqueeze(-1)
        output = model(
            states=state,
            actions=action,
            returns_to_go=rtg,
            timesteps=timesteps
        )

        action_preds = output.action_preds
        action_targets = action.argmax(dim=-1)

        loss = torch.nn.functional.cross_entropy(action_preds.reshape(-1, 18),
            action_targets.reshape(-1))

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        if batch_idx % 100 == 0:
            print(f"Epoch {epoch}, Batch {batch_idx}, Loss: {loss.item():.4f}")
        
        batch_idx += 1
    
    print(f"Epoch {epoch} Average Loss: {total_loss / len(dataloader):.4f}")
# Out:
# Linear(in_features=4608, out_features=128, bias=True)
# Embedding(4096, 128)
# Linear(in_features=18, out_features=128, bias=True)
# Epoch 0 Average Loss: 2.5397
# Epoch 1 Average Loss: 2.1611
# Epoch 2 Average Loss: 2.0659
# Epoch 3 Average Loss: 1.9389
# Epoch 4 Average Loss: 1.9744
# Epoch 5 Average Loss: 1.9257
# Epoch 6 Average Loss: 1.8395
# Epoch 7 Average Loss: 1.8218
# Epoch 8 Average Loss: 1.7699
# Epoch 9 Average Loss: 1.6390
