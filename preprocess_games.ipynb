# %%
from pathlib import Path
from npz_loader import discover_game_npz_paths, get_sequences_by_game, fix_obs_paths
from atari_preprocess import preprocess_one_sequence, find_image_folders



# 1. GAME ROOT DIRECTORY (Pick any game)
train_game_dirs = [
    Path("dataset/MsPacmanNoFrameskip-v4/BeamRiderNoFrameskip-v4"),
    Path("dataset/BreakoutNoFrameskip-v4/BreakoutNoFrameskip-v4"),
    Path("dataset/MsPacmanNoFrameskip-v4/EnduroNoFrameskip-v4"),
    Path("dataset/BreakoutNoFrameskip-v4/MsPacmanNoFrameskip-v4"),
    Path("dataset/MsPacmanNoFrameskip-v4/QbertNoFrameskip-v4"),
    Path("dataset/BreakoutNoFrameskip-v4/SeaquestNoFrameskip-v4"),
    Path("dataset/BreakoutNoFrameskip-v4/SpaceInvadersNoFrameskip-v4"),
]
game_tokens = []
for game_root in train_game_dirs:

    # 2. Load ALL NPZ files (already sorted by discover_game_npz_paths)
    npz_paths_by_game = discover_game_npz_paths([game_root])
    game_to_sequences = get_sequences_by_game(npz_paths_by_game)
    sequences_by_game = fix_obs_paths(game_to_sequences, dataset_root="dataset")

    game_key = list(sequences_by_game.keys())[0]
    npz_sequences = sequences_by_game[game_key]

    print(f"Found {len(npz_sequences)} NPZ sequences.")

    # 3. Load ALL image folders for this game
    image_folders = find_image_folders(game_root)
    print(f"Found {len(image_folders)} image folders.")

    if len(image_folders) != len(npz_sequences):
        print("WARNING: NPZ count and image folder count differ!")
        print("Index pairing may need manual correction!")

    # 4. Preprocess ALL sequences into token lists
    all_token_lists = []

    for idx, npz_seq in enumerate(npz_sequences):
        img_folder = image_folders[idx]
        print(f"\nProcessing episode {idx}/{len(npz_sequences)-1}")
        print(f"NPZ ↔ {img_folder.name}")

        tokens = preprocess_one_sequence(
            npz_seq=npz_seq,
            game_root=game_root,
            seq_index=idx    # episode index
        )

        print(f" → Tokens created: {len(tokens)}")

        all_token_lists.append(tokens)

    print("\n======== PREPROCESSING COMPLETE ========")
    print(f"Total episodes processed: {len(all_token_lists)}")
    print(f"Example episode #0 token count: {len(all_token_lists[0])}")
    game_tokens.append(all_token_lists)
# Out:
# Found 480 NPZ sequences.
# Found 480 image folders.
#
# Processing episode 0/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-0
#  → Tokens created: 21996
#
# Processing episode 1/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-1
#  → Tokens created: 4797
#
# Processing episode 2/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-2
#  → Tokens created: 12480
#
# Processing episode 3/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-3
#  → Tokens created: 17979
#
# Processing episode 4/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-4
#  → Tokens created: 9789
#
# Processing episode 5/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-5
#  → Tokens created: 21294
#
# Processing episode 6/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-6
#  → Tokens created: 3588
#
# Processing episode 7/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-7
#  → Tokens created: 20592
#
# Processing episode 8/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-8
#  → Tokens created: 18408
#
# Processing episode 9/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-9
#  → Tokens created: 10140
#
# Processing episode 10/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10
#  → Tokens created: 22425
#
# Processing episode 11/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-11
#  → Tokens created: 7488
#
# Processing episode 12/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-12
#  → Tokens created: 19305
#
# Processing episode 13/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-13
#  → Tokens created: 21567
#
# Processing episode 14/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-14
#  → Tokens created: 18252
#
# Processing episode 15/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-15
#  → Tokens created: 7215
#
# Processing episode 16/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-16
#  → Tokens created: 20202
#
# Processing episode 17/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-17
#  → Tokens created: 19188
#
# Processing episode 18/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-18
#  → Tokens created: 22659
#
# Processing episode 19/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-19
#  → Tokens created: 21138
#
# Processing episode 20/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20
#  → Tokens created: 7995
#
# Processing episode 21/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-21
#  → Tokens created: 22035
#
# Processing episode 22/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-22
#  → Tokens created: 17160
#
# Processing episode 23/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-23
#  → Tokens created: 12129
#
# Processing episode 24/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-24
#  → Tokens created: 13182
#
# Processing episode 25/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-25
#  → Tokens created: 9048
#
# Processing episode 26/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-26
#  → Tokens created: 5577
#
# Processing episode 27/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-27
#  → Tokens created: 12480
#
# Processing episode 28/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-28
#  → Tokens created: 17082
#
# Processing episode 29/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-29
#  → Tokens created: 3003
#
# Processing episode 30/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-30
#  → Tokens created: 16419
#
# Processing episode 31/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-31
#  → Tokens created: 17550
#
# Processing episode 32/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-32
#  → Tokens created: 4602
#
# Processing episode 33/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-33
#  → Tokens created: 7020
#
# Processing episode 34/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-34
#  → Tokens created: 17199
#
# Processing episode 35/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-35
#  → Tokens created: 12714
#
# Processing episode 36/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-36
#  → Tokens created: 13806
#
# Processing episode 37/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-37
#  → Tokens created: 19344
#
# Processing episode 38/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-38
#  → Tokens created: 6981
#
# Processing episode 39/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-39
#  → Tokens created: 7527
#
# Processing episode 40/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-40
#  → Tokens created: 7098
#
# Processing episode 41/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-41
#  → Tokens created: 8268
#
# Processing episode 42/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-42
#  → Tokens created: 17082
#
# Processing episode 43/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-43
#  → Tokens created: 20163
#
# Processing episode 44/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-44
#  → Tokens created: 12363
#
# Processing episode 45/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-45
#  → Tokens created: 18447
#
# Processing episode 46/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-46
#  → Tokens created: 18252
#
# Processing episode 47/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-47
#  → Tokens created: 7176
#
# Processing episode 48/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-48
#  → Tokens created: 7098
#
# Processing episode 49/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-49
#  → Tokens created: 12519
#
# Processing episode 50/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-50
#  → Tokens created: 15132
#
# Processing episode 51/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-51
#  → Tokens created: 21450
#
# Processing episode 52/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-52
#  → Tokens created: 11349
#
# Processing episode 53/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-53
#  → Tokens created: 7215
#
# Processing episode 54/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-54
#  → Tokens created: 7371
#
# Processing episode 55/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-55
#  → Tokens created: 26676
#
# Processing episode 56/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-56
#  → Tokens created: 6864
#
# Processing episode 57/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-57
#  → Tokens created: 10335
#
# Processing episode 58/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-58
#  → Tokens created: 21255
#
# Processing episode 59/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-59
#  → Tokens created: 3159
#
# Processing episode 60/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-60
#  → Tokens created: 3042
#
# Processing episode 61/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-61
#  → Tokens created: 26754
#
# Processing episode 62/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-62
#  → Tokens created: 15132
#
# Processing episode 63/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-63
#  → Tokens created: 4446
#
# Processing episode 64/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-64
#  → Tokens created: 1053
#
# Processing episode 65/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-65
#  → Tokens created: 22503
#
# Processing episode 66/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-66
#  → Tokens created: 22035
#
# Processing episode 67/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-67
#  → Tokens created: 22620
#
# Processing episode 68/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-68
#  → Tokens created: 12519
#
# Processing episode 69/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-69
#  → Tokens created: 14313
#
# Processing episode 70/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-70
#  → Tokens created: 17160
#
# Processing episode 71/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-71
#  → Tokens created: 7215
#
# Processing episode 72/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-72
#  → Tokens created: 18018
#
# Processing episode 73/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-73
#  → Tokens created: 7488
#
# Processing episode 74/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-74
#  → Tokens created: 21723
#
# Processing episode 75/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-75
#  → Tokens created: 12168
#
# Processing episode 76/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-76
#  → Tokens created: 21216
#
# Processing episode 77/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-77
#  → Tokens created: 18135
#
# Processing episode 78/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-78
#  → Tokens created: 17082
#
# Processing episode 79/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-79
#  → Tokens created: 7371
#
# Processing episode 80/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-80
#  → Tokens created: 12246
#
# Processing episode 81/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-81
#  → Tokens created: 22386
#
# Processing episode 82/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-82
#  → Tokens created: 7059
#
# Processing episode 83/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-83
#  → Tokens created: 7098
#
# Processing episode 84/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-84
#  → Tokens created: 4251
#
# Processing episode 85/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-85
#  → Tokens created: 4290
#
# Processing episode 86/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-86
#  → Tokens created: 23361
#
# Processing episode 87/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-87
#  → Tokens created: 3744
#
# Processing episode 88/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-88
#  → Tokens created: 1326
#
# Processing episode 89/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-89
#  → Tokens created: 7098
#
# Processing episode 90/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-90
#  → Tokens created: 7215
#
# Processing episode 91/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-91
#  → Tokens created: 16770
#
# Processing episode 92/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-92
#  → Tokens created: 3432
#
# Processing episode 93/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-93
#  → Tokens created: 17199
#
# Processing episode 94/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-94
#  → Tokens created: 21060
#
# Processing episode 95/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-95
#  → Tokens created: 3081
#
# Processing episode 96/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-96
#  → Tokens created: 7098
#
# Processing episode 97/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-97
#  → Tokens created: 14898
#
# Processing episode 98/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-98
#  → Tokens created: 20748
#
# Processing episode 99/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-99
#  → Tokens created: 11505
#
# Processing episode 100/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-100
#  → Tokens created: 27105
#
# Processing episode 101/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-101
#  → Tokens created: 23400
#
# Processing episode 102/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-102
#  → Tokens created: 22971
#
# Processing episode 103/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-103
#  → Tokens created: 21450
#
# Processing episode 104/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-104
#  → Tokens created: 20943
#
# Processing episode 105/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-105
#  → Tokens created: 7020
#
# Processing episode 106/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-106
#  → Tokens created: 7410
#
# Processing episode 107/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-107
#  → Tokens created: 7176
#
# Processing episode 108/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-108
#  → Tokens created: 7059
#
# Processing episode 109/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-109
#  → Tokens created: 7098
#
# Processing episode 110/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-110
#  → Tokens created: 22620
#
# Processing episode 111/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-111
#  → Tokens created: 22113
#
# Processing episode 112/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-112
#  → Tokens created: 24765
#
# Processing episode 113/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-113
#  → Tokens created: 15054
#
# Processing episode 114/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-114
#  → Tokens created: 4212
#
# Processing episode 115/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-115
#  → Tokens created: 7254
#
# Processing episode 116/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-116
#  → Tokens created: 4134
#
# Processing episode 117/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-117
#  → Tokens created: 12480
#
# Processing episode 118/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-118
#  → Tokens created: 12948
#
# Processing episode 119/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-119
#  → Tokens created: 8424
#
# Processing episode 120/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-120
#  → Tokens created: 20436
#
# Processing episode 121/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-121
#  → Tokens created: 11544
#
# Processing episode 122/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-122
#  → Tokens created: 22776
#
# Processing episode 123/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-123
#  → Tokens created: 14079
#
# Processing episode 124/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-124
#  → Tokens created: 6981
#
# Processing episode 125/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-125
#  → Tokens created: 1755
#
# Processing episode 126/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-126
#  → Tokens created: 4407
#
# Processing episode 127/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-127
#  → Tokens created: 23166
#
# Processing episode 128/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-128
#  → Tokens created: 4485
#
# Processing episode 129/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-129
#  → Tokens created: 6981
#
# Processing episode 130/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-130
#  → Tokens created: 22425
#
# Processing episode 131/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-131
#  → Tokens created: 6981
#
# Processing episode 132/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-132
#  → Tokens created: 12402
#
# Processing episode 133/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-133
#  → Tokens created: 19266
#
# Processing episode 134/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-134
#  → Tokens created: 7098
#
# Processing episode 135/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-135
#  → Tokens created: 18642
#
# Processing episode 136/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-136
#  → Tokens created: 7449
#
# Processing episode 137/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-137
#  → Tokens created: 7293
#
# Processing episode 138/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-138
#  → Tokens created: 7527
#
# Processing episode 139/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-139
#  → Tokens created: 19539
#
# Processing episode 140/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-140
#  → Tokens created: 4173
#
# Processing episode 141/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-141
#  → Tokens created: 4095
#
# Processing episode 142/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-142
#  → Tokens created: 19773
#
# Processing episode 143/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-143
#  → Tokens created: 17160
#
# Processing episode 144/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-144
#  → Tokens created: 4173
#
# Processing episode 145/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-145
#  → Tokens created: 21216
#
# Processing episode 146/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-146
#  → Tokens created: 18291
#
# Processing episode 147/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-147
#  → Tokens created: 12519
#
# Processing episode 148/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-148
#  → Tokens created: 7254
#
# Processing episode 149/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-149
#  → Tokens created: 18408
#
# Processing episode 150/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-150
#  → Tokens created: 4524
#
# Processing episode 151/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-151
#  → Tokens created: 18135
#
# Processing episode 152/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-152
#  → Tokens created: 12363
#
# Processing episode 153/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-153
#  → Tokens created: 7020
#
# Processing episode 154/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-154
#  → Tokens created: 3120
#
# Processing episode 155/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-155
#  → Tokens created: 22386
#
# Processing episode 156/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-156
#  → Tokens created: 4212
#
# Processing episode 157/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-157
#  → Tokens created: 13689
#
# Processing episode 158/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-158
#  → Tokens created: 4212
#
# Processing episode 159/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-159
#  → Tokens created: 21918
#
# Processing episode 160/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-160
#  → Tokens created: 7020
#
# Processing episode 161/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-161
#  → Tokens created: 6864
#
# Processing episode 162/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-162
#  → Tokens created: 12246
#
# Processing episode 163/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-163
#  → Tokens created: 12402
#
# Processing episode 164/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-164
#  → Tokens created: 7293
#
# Processing episode 165/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-165
#  → Tokens created: 22425
#
# Processing episode 166/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-166
#  → Tokens created: 17472
#
# Processing episode 167/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-167
#  → Tokens created: 18291
#
# Processing episode 168/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-168
#  → Tokens created: 4251
#
# Processing episode 169/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-169
#  → Tokens created: 19071
#
# Processing episode 170/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-170
#  → Tokens created: 7293
#
# Processing episode 171/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-171
#  → Tokens created: 21216
#
# Processing episode 172/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-172
#  → Tokens created: 3783
#
# Processing episode 173/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-173
#  → Tokens created: 22815
#
# Processing episode 174/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-174
#  → Tokens created: 8424
#
# Processing episode 175/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-175
#  → Tokens created: 7293
#
# Processing episode 176/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-176
#  → Tokens created: 12246
#
# Processing episode 177/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-177
#  → Tokens created: 24570
#
# Processing episode 178/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-178
#  → Tokens created: 12402
#
# Processing episode 179/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-179
#  → Tokens created: 15639
#
# Processing episode 180/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-180
#  → Tokens created: 7995
#
# Processing episode 181/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-181
#  → Tokens created: 9633
#
# Processing episode 182/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-182
#  → Tokens created: 7332
#
# Processing episode 183/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-183
#  → Tokens created: 22776
#
# Processing episode 184/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-184
#  → Tokens created: 22737
#
# Processing episode 185/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-185
#  → Tokens created: 10569
#
# Processing episode 186/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-186
#  → Tokens created: 4329
#
# Processing episode 187/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-187
#  → Tokens created: 17784
#
# Processing episode 188/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-188
#  → Tokens created: 4797
#
# Processing episode 189/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-189
#  → Tokens created: 22815
#
# Processing episode 190/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-190
#  → Tokens created: 21450
#
# Processing episode 191/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-191
#  → Tokens created: 7059
#
# Processing episode 192/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-192
#  → Tokens created: 12246
#
# Processing episode 193/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-193
#  → Tokens created: 7215
#
# Processing episode 194/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-194
#  → Tokens created: 12402
#
# Processing episode 195/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-195
#  → Tokens created: 18252
#
# Processing episode 196/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-196
#  → Tokens created: 21294
#
# Processing episode 197/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-197
#  → Tokens created: 9555
#
# Processing episode 198/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-198
#  → Tokens created: 17082
#
# Processing episode 199/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-199
#  → Tokens created: 5187
#
# Processing episode 200/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-200
#  → Tokens created: 3237
#
# Processing episode 201/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-201
#  → Tokens created: 7293
#
# Processing episode 202/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-202
#  → Tokens created: 13494
#
# Processing episode 203/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-203
#  → Tokens created: 3003
#
# Processing episode 204/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-204
#  → Tokens created: 17004
#
# Processing episode 205/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-205
#  → Tokens created: 18720
#
# Processing episode 206/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-206
#  → Tokens created: 12246
#
# Processing episode 207/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-207
#  → Tokens created: 18837
#
# Processing episode 208/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-208
#  → Tokens created: 21255
#
# Processing episode 209/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-209
#  → Tokens created: 21918
#
# Processing episode 210/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-210
#  → Tokens created: 6903
#
# Processing episode 211/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-211
#  → Tokens created: 3120
#
# Processing episode 212/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-212
#  → Tokens created: 4056
#
# Processing episode 213/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-213
#  → Tokens created: 12402
#
# Processing episode 214/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-214
#  → Tokens created: 5031
#
# Processing episode 215/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-215
#  → Tokens created: 17901
#
# Processing episode 216/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-216
#  → Tokens created: 22620
#
# Processing episode 217/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-217
#  → Tokens created: 7215
#
# Processing episode 218/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-218
#  → Tokens created: 12948
#
# Processing episode 219/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-219
#  → Tokens created: 6981
#
# Processing episode 220/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-220
#  → Tokens created: 17979
#
# Processing episode 221/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-221
#  → Tokens created: 16419
#
# Processing episode 222/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-222
#  → Tokens created: 19266
#
# Processing episode 223/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-223
#  → Tokens created: 17199
#
# Processing episode 224/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-224
#  → Tokens created: 20007
#
# Processing episode 225/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-225
#  → Tokens created: 17082
#
# Processing episode 226/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-226
#  → Tokens created: 9633
#
# Processing episode 227/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-227
#  → Tokens created: 10686
#
# Processing episode 228/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-228
#  → Tokens created: 7488
#
# Processing episode 229/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-229
#  → Tokens created: 3198
#
# Processing episode 230/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-230
#  → Tokens created: 4524
#
# Processing episode 231/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-231
#  → Tokens created: 17199
#
# Processing episode 232/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-232
#  → Tokens created: 21177
#
# Processing episode 233/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-233
#  → Tokens created: 18018
#
# Processing episode 234/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-234
#  → Tokens created: 13767
#
# Processing episode 235/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-235
#  → Tokens created: 4368
#
# Processing episode 236/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-236
#  → Tokens created: 22386
#
# Processing episode 237/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-237
#  → Tokens created: 22308
#
# Processing episode 238/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-238
#  → Tokens created: 10764
#
# Processing episode 239/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-239
#  → Tokens created: 4407
#
# Processing episode 240/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-240
#  → Tokens created: 20943
#
# Processing episode 241/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-241
#  → Tokens created: 16887
#
# Processing episode 242/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-242
#  → Tokens created: 17550
#
# Processing episode 243/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-243
#  → Tokens created: 21138
#
# Processing episode 244/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-244
#  → Tokens created: 13416
#
# Processing episode 245/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-245
#  → Tokens created: 21138
#
# Processing episode 246/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-246
#  → Tokens created: 23868
#
# Processing episode 247/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-247
#  → Tokens created: 12129
#
# Processing episode 248/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-248
#  → Tokens created: 7332
#
# Processing episode 249/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-249
#  → Tokens created: 6981
#
# Processing episode 250/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-250
#  → Tokens created: 7254
#
# Processing episode 251/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-251
#  → Tokens created: 22737
#
# Processing episode 252/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-252
#  → Tokens created: 21996
#
# Processing episode 253/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-253
#  → Tokens created: 21333
#
# Processing episode 254/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-254
#  → Tokens created: 14118
#
# Processing episode 255/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-255
#  → Tokens created: 17784
#
# Processing episode 256/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-256
#  → Tokens created: 22230
#
# Processing episode 257/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-257
#  → Tokens created: 14469
#
# Processing episode 258/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-258
#  → Tokens created: 20748
#
# Processing episode 259/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-259
#  → Tokens created: 4602
#
# Processing episode 260/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-260
#  → Tokens created: 21528
#
# Processing episode 261/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-261
#  → Tokens created: 13572
#
# Processing episode 262/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-262
#  → Tokens created: 3120
#
# Processing episode 263/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-263
#  → Tokens created: 21528
#
# Processing episode 264/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-264
#  → Tokens created: 13572
#
# Processing episode 265/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-265
#  → Tokens created: 8853
#
# Processing episode 266/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-266
#  → Tokens created: 3198
#
# Processing episode 267/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-267
#  → Tokens created: 17004
#
# Processing episode 268/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-268
#  → Tokens created: 4407
#
# Processing episode 269/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-269
#  → Tokens created: 19149
#
# Processing episode 270/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-270
#  → Tokens created: 10023
#
# Processing episode 271/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-271
#  → Tokens created: 5928
#
# Processing episode 272/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-272
#  → Tokens created: 11505
#
# Processing episode 273/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-273
#  → Tokens created: 13221
#
# Processing episode 274/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-274
#  → Tokens created: 23127
#
# Processing episode 275/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-275
#  → Tokens created: 24492
#
# Processing episode 276/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-276
#  → Tokens created: 20592
#
# Processing episode 277/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-277
#  → Tokens created: 12480
#
# Processing episode 278/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-278
#  → Tokens created: 23634
#
# Processing episode 279/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-279
#  → Tokens created: 22113
#
# Processing episode 280/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-280
#  → Tokens created: 14079
#
# Processing episode 281/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-281
#  → Tokens created: 7020
#
# Processing episode 282/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-282
#  → Tokens created: 12948
#
# Processing episode 283/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-283
#  → Tokens created: 12402
#
# Processing episode 284/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-284
#  → Tokens created: 12402
#
# Processing episode 285/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-285
#  → Tokens created: 4290
#
# Processing episode 286/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-286
#  → Tokens created: 20046
#
# Processing episode 287/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-287
#  → Tokens created: 14976
#
# Processing episode 288/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-288
#  → Tokens created: 7332
#
# Processing episode 289/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-289
#  → Tokens created: 3042
#
# Processing episode 290/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-290
#  → Tokens created: 18018
#
# Processing episode 291/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-291
#  → Tokens created: 9360
#
# Processing episode 292/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-292
#  → Tokens created: 3003
#
# Processing episode 293/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-293
#  → Tokens created: 12246
#
# Processing episode 294/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-294
#  → Tokens created: 22503
#
# Processing episode 295/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-295
#  → Tokens created: 4329
#
# Processing episode 296/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-296
#  → Tokens created: 12246
#
# Processing episode 297/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-297
#  → Tokens created: 3042
#
# Processing episode 298/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-298
#  → Tokens created: 22698
#
# Processing episode 299/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-299
#  → Tokens created: 17862
#
# Processing episode 300/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-300
#  → Tokens created: 5499
#
# Processing episode 301/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-301
#  → Tokens created: 14742
#
# Processing episode 302/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-302
#  → Tokens created: 17277
#
# Processing episode 303/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-303
#  → Tokens created: 16965
#
# Processing episode 304/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-304
#  → Tokens created: 13923
#
# Processing episode 305/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-305
#  → Tokens created: 19344
#
# Processing episode 306/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-306
#  → Tokens created: 13923
#
# Processing episode 307/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-307
#  → Tokens created: 6942
#
# Processing episode 308/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-308
#  → Tokens created: 7410
#
# Processing episode 309/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-309
#  → Tokens created: 7176
#
# Processing episode 310/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-310
#  → Tokens created: 18603
#
# Processing episode 311/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-311
#  → Tokens created: 21411
#
# Processing episode 312/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-312
#  → Tokens created: 13650
#
# Processing episode 313/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-313
#  → Tokens created: 23049
#
# Processing episode 314/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-314
#  → Tokens created: 12402
#
# Processing episode 315/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-315
#  → Tokens created: 10335
#
# Processing episode 316/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-316
#  → Tokens created: 17589
#
# Processing episode 317/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-317
#  → Tokens created: 12246
#
# Processing episode 318/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-318
#  → Tokens created: 7137
#
# Processing episode 319/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-319
#  → Tokens created: 4017
#
# Processing episode 320/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10000
#  → Tokens created: 3783
#
# Processing episode 321/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10001
#  → Tokens created: 9243
#
# Processing episode 322/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10002
#  → Tokens created: 20631
#
# Processing episode 323/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10003
#  → Tokens created: 12324
#
# Processing episode 324/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10004
#  → Tokens created: 5460
#
# Processing episode 325/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10005
#  → Tokens created: 7644
#
# Processing episode 326/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10006
#  → Tokens created: 5226
#
# Processing episode 327/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10007
#  → Tokens created: 17004
#
# Processing episode 328/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10008
#  → Tokens created: 3198
#
# Processing episode 329/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10009
#  → Tokens created: 4212
#
# Processing episode 330/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10010
#  → Tokens created: 4407
#
# Processing episode 331/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10011
#  → Tokens created: 9945
#
# Processing episode 332/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10012
#  → Tokens created: 6942
#
# Processing episode 333/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10013
#  → Tokens created: 10803
#
# Processing episode 334/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10014
#  → Tokens created: 21255
#
# Processing episode 335/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10015
#  → Tokens created: 7293
#
# Processing episode 336/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10016
#  → Tokens created: 4329
#
# Processing episode 337/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10017
#  → Tokens created: 12714
#
# Processing episode 338/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10018
#  → Tokens created: 13182
#
# Processing episode 339/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10019
#  → Tokens created: 10140
#
# Processing episode 340/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10020
#  → Tokens created: 19851
#
# Processing episode 341/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10021
#  → Tokens created: 13650
#
# Processing episode 342/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10022
#  → Tokens created: 4251
#
# Processing episode 343/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10023
#  → Tokens created: 22620
#
# Processing episode 344/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10024
#  → Tokens created: 5577
#
# Processing episode 345/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10025
#  → Tokens created: 12636
#
# Processing episode 346/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10026
#  → Tokens created: 8580
#
# Processing episode 347/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10027
#  → Tokens created: 9516
#
# Processing episode 348/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10028
#  → Tokens created: 11388
#
# Processing episode 349/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10029
#  → Tokens created: 5382
#
# Processing episode 350/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10030
#  → Tokens created: 4407
#
# Processing episode 351/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10031
#  → Tokens created: 18408
#
# Processing episode 352/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10032
#  → Tokens created: 19422
#
# Processing episode 353/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10033
#  → Tokens created: 10335
#
# Processing episode 354/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10034
#  → Tokens created: 3549
#
# Processing episode 355/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10035
#  → Tokens created: 3198
#
# Processing episode 356/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10036
#  → Tokens created: 4290
#
# Processing episode 357/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10037
#  → Tokens created: 24180
#
# Processing episode 358/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10038
#  → Tokens created: 3471
#
# Processing episode 359/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10039
#  → Tokens created: 5460
#
# Processing episode 360/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10040
#  → Tokens created: 4797
#
# Processing episode 361/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10041
#  → Tokens created: 9555
#
# Processing episode 362/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10042
#  → Tokens created: 5148
#
# Processing episode 363/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10043
#  → Tokens created: 5031
#
# Processing episode 364/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10044
#  → Tokens created: 4251
#
# Processing episode 365/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10045
#  → Tokens created: 13689
#
# Processing episode 366/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10046
#  → Tokens created: 4485
#
# Processing episode 367/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10047
#  → Tokens created: 4095
#
# Processing episode 368/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10048
#  → Tokens created: 12246
#
# Processing episode 369/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10049
#  → Tokens created: 5499
#
# Processing episode 370/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10050
#  → Tokens created: 12246
#
# Processing episode 371/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10051
#  → Tokens created: 4212
#
# Processing episode 372/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10052
#  → Tokens created: 7176
#
# Processing episode 373/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10053
#  → Tokens created: 4173
#
# Processing episode 374/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10054
#  → Tokens created: 10686
#
# Processing episode 375/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10055
#  → Tokens created: 9945
#
# Processing episode 376/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10056
#  → Tokens created: 9633
#
# Processing episode 377/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10057
#  → Tokens created: 17901
#
# Processing episode 378/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10058
#  → Tokens created: 7644
#
# Processing episode 379/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10059
#  → Tokens created: 3276
#
# Processing episode 380/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10060
#  → Tokens created: 7488
#
# Processing episode 381/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10061
#  → Tokens created: 17277
#
# Processing episode 382/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10062
#  → Tokens created: 3081
#
# Processing episode 383/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10063
#  → Tokens created: 507
#
# Processing episode 384/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10064
#  → Tokens created: 5928
#
# Processing episode 385/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10065
#  → Tokens created: 20046
#
# Processing episode 386/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10066
#  → Tokens created: 12480
#
# Processing episode 387/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10067
#  → Tokens created: 3939
#
# Processing episode 388/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10068
#  → Tokens created: 4329
#
# Processing episode 389/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10069
#  → Tokens created: 5187
#
# Processing episode 390/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10070
#  → Tokens created: 10023
#
# Processing episode 391/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10071
#  → Tokens created: 14976
#
# Processing episode 392/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10072
#  → Tokens created: 10803
#
# Processing episode 393/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10073
#  → Tokens created: 20904
#
# Processing episode 394/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10074
#  → Tokens created: 14976
#
# Processing episode 395/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10075
#  → Tokens created: 14742
#
# Processing episode 396/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10076
#  → Tokens created: 4407
#
# Processing episode 397/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10077
#  → Tokens created: 12636
#
# Processing episode 398/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10078
#  → Tokens created: 8424
#
# Processing episode 399/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-10079
#  → Tokens created: 4212
#
# Processing episode 400/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20000
#  → Tokens created: 3783
#
# Processing episode 401/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20001
#  → Tokens created: 3042
#
# Processing episode 402/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20002
#  → Tokens created: 3198
#
# Processing episode 403/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20003
#  → Tokens created: 7293
#
# Processing episode 404/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20004
#  → Tokens created: 8853
#
# Processing episode 405/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20005
#  → Tokens created: 3003
#
# Processing episode 406/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20006
#  → Tokens created: 4602
#
# Processing episode 407/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20007
#  → Tokens created: 10764
#
# Processing episode 408/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20008
#  → Tokens created: 5226
#
# Processing episode 409/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20009
#  → Tokens created: 19929
#
# Processing episode 410/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20010
#  → Tokens created: 3198
#
# Processing episode 411/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20011
#  → Tokens created: 4329
#
# Processing episode 412/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20012
#  → Tokens created: 3120
#
# Processing episode 413/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20013
#  → Tokens created: 4368
#
# Processing episode 414/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20014
#  → Tokens created: 4017
#
# Processing episode 415/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20015
#  → Tokens created: 18330
#
# Processing episode 416/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20016
#  → Tokens created: 13104
#
# Processing episode 417/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20017
#  → Tokens created: 3315
#
# Processing episode 418/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20018
#  → Tokens created: 18837
#
# Processing episode 419/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20019
#  → Tokens created: 3120
#
# Processing episode 420/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20020
#  → Tokens created: 3003
#
# Processing episode 421/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20021
#  → Tokens created: 3003
#
# Processing episode 422/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20022
#  → Tokens created: 3198
#
# Processing episode 423/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20023
#  → Tokens created: 4056
#
# Processing episode 424/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20024
#  → Tokens created: 11583
#
# Processing episode 425/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20025
#  → Tokens created: 4524
#
# Processing episode 426/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20026
#  → Tokens created: 4407
#
# Processing episode 427/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20027
#  → Tokens created: 17160
#
# Processing episode 428/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20028
#  → Tokens created: 21918
#
# Processing episode 429/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20029
#  → Tokens created: 4329
#
# Processing episode 430/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20030
#  → Tokens created: 3783
#
# Processing episode 431/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20031
#  → Tokens created: 17043
#
# Processing episode 432/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20032
#  → Tokens created: 1755
#
# Processing episode 433/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20033
#  → Tokens created: 4173
#
# Processing episode 434/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20034
#  → Tokens created: 10569
#
# Processing episode 435/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20035
#  → Tokens created: 3237
#
# Processing episode 436/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20036
#  → Tokens created: 4524
#
# Processing episode 437/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20037
#  → Tokens created: 3120
#
# Processing episode 438/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20038
#  → Tokens created: 4407
#
# Processing episode 439/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20039
#  → Tokens created: 3042
#
# Processing episode 440/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20040
#  → Tokens created: 3081
#
# Processing episode 441/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20041
#  → Tokens created: 3120
#
# Processing episode 442/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20042
#  → Tokens created: 1326
#
# Processing episode 443/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20043
#  → Tokens created: 4446
#
# Processing episode 444/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20044
#  → Tokens created: 3003
#
# Processing episode 445/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20045
#  → Tokens created: 9789
#
# Processing episode 446/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20046
#  → Tokens created: 12714
#
# Processing episode 447/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20047
#  → Tokens created: 3042
#
# Processing episode 448/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20048
#  → Tokens created: 3003
#
# Processing episode 449/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20049
#  → Tokens created: 3120
#
# Processing episode 450/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20050
#  → Tokens created: 4602
#
# Processing episode 451/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20051
#  → Tokens created: 3081
#
# Processing episode 452/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20052
#  → Tokens created: 13806
#
# Processing episode 453/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20053
#  → Tokens created: 3159
#
# Processing episode 454/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20054
#  → Tokens created: 3432
#
# Processing episode 455/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20055
#  → Tokens created: 8424
#
# Processing episode 456/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20056
#  → Tokens created: 3744
#
# Processing episode 457/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20057
#  → Tokens created: 1053
#
# Processing episode 458/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20058
#  → Tokens created: 3471
#
# Processing episode 459/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20059
#  → Tokens created: 3276
#
# Processing episode 460/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20060
#  → Tokens created: 7176
#
# Processing episode 461/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20061
#  → Tokens created: 3081
#
# Processing episode 462/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20062
#  → Tokens created: 3315
#
# Processing episode 463/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20063
#  → Tokens created: 3159
#
# Processing episode 464/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20064
#  → Tokens created: 3198
#
# Processing episode 465/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20065
#  → Tokens created: 3081
#
# Processing episode 466/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20066
#  → Tokens created: 4446
#
# Processing episode 467/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20067
#  → Tokens created: 3939
#
# Processing episode 468/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20068
#  → Tokens created: 7215
#
# Processing episode 469/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20069
#  → Tokens created: 11544
#
# Processing episode 470/479
# NPZ ↔ MsPacmanNoFrameskip-v4-recorded_images-20070
#  → Tokens created: 3549
#
# Processing episode 471/479
# ...
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-41
#  → Tokens created: 3276
#
# Processing episode 42/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-42
#  → Tokens created: 7332
#
# Processing episode 43/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-43
#  → Tokens created: 897
#
# Processing episode 44/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-44
#  → Tokens created: 3276
#
# Processing episode 45/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-45
#  → Tokens created: 8736
#
# Processing episode 46/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-46
#  → Tokens created: 7644
#
# Processing episode 47/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-47
#  → Tokens created: 897
#
# Processing episode 48/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-48
#  → Tokens created: 897
#
# Processing episode 49/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-49
#  → Tokens created: 10725
#
# Processing episode 50/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-50
#  → Tokens created: 2769
#
# Processing episode 51/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-51
#  → Tokens created: 1989
#
# Processing episode 52/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-52
#  → Tokens created: 2769
#
# Processing episode 53/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-53
#  → Tokens created: 2769
#
# Processing episode 54/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-54
#  → Tokens created: 6045
#
# Processing episode 55/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-55
#  → Tokens created: 2691
#
# Processing episode 56/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-56
#  → Tokens created: 7332
#
# Processing episode 57/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-57
#  → Tokens created: 1989
#
# Processing episode 58/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-58
#  → Tokens created: 8580
#
# Processing episode 59/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-59
#  → Tokens created: 3861
#
# Processing episode 60/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-60
#  → Tokens created: 1989
#
# Processing episode 61/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-61
#  → Tokens created: 6552
#
# Processing episode 62/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-62
#  → Tokens created: 2769
#
# Processing episode 63/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-63
#  → Tokens created: 5772
#
# Processing episode 64/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-64
#  → Tokens created: 6630
#
# Processing episode 65/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-65
#  → Tokens created: 897
#
# Processing episode 66/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-66
#  → Tokens created: 6591
#
# Processing episode 67/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-67
#  → Tokens created: 9243
#
# Processing episode 68/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-68
#  → Tokens created: 6084
#
# Processing episode 69/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-69
#  → Tokens created: 8580
#
# Processing episode 70/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-70
#  → Tokens created: 1989
#
# Processing episode 71/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-71
#  → Tokens created: 2769
#
# Processing episode 72/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-72
#  → Tokens created: 897
#
# Processing episode 73/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-73
#  → Tokens created: 3276
#
# Processing episode 74/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-74
#  → Tokens created: 897
#
# Processing episode 75/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-75
#  → Tokens created: 6396
#
# Processing episode 76/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-76
#  → Tokens created: 897
#
# Processing episode 77/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-77
#  → Tokens created: 897
#
# Processing episode 78/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-78
#  → Tokens created: 1989
#
# Processing episode 79/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-79
#  → Tokens created: 3354
#
# Processing episode 80/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-80
#  → Tokens created: 4641
#
# Processing episode 81/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-81
#  → Tokens created: 1989
#
# Processing episode 82/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-82
#  → Tokens created: 5031
#
# Processing episode 83/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-83
#  → Tokens created: 7605
#
# Processing episode 84/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-84
#  → Tokens created: 5967
#
# Processing episode 85/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-85
#  → Tokens created: 897
#
# Processing episode 86/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-86
#  → Tokens created: 6591
#
# Processing episode 87/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-87
#  → Tokens created: 3276
#
# Processing episode 88/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-88
#  → Tokens created: 2769
#
# Processing episode 89/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-89
#  → Tokens created: 1989
#
# Processing episode 90/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-90
#  → Tokens created: 3900
#
# Processing episode 91/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-91
#  → Tokens created: 3276
#
# Processing episode 92/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-92
#  → Tokens created: 1989
#
# Processing episode 93/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-93
#  → Tokens created: 3354
#
# Processing episode 94/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-94
#  → Tokens created: 1989
#
# Processing episode 95/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-95
#  → Tokens created: 897
#
# Processing episode 96/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-96
#  → Tokens created: 6864
#
# Processing episode 97/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-97
#  → Tokens created: 2769
#
# Processing episode 98/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-98
#  → Tokens created: 3861
#
# Processing episode 99/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-99
#  → Tokens created: 3354
#
# Processing episode 100/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-100
#  → Tokens created: 1989
#
# Processing episode 101/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-101
#  → Tokens created: 3276
#
# Processing episode 102/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-102
#  → Tokens created: 897
#
# Processing episode 103/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-103
#  → Tokens created: 2691
#
# Processing episode 104/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-104
#  → Tokens created: 2769
#
# Processing episode 105/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-105
#  → Tokens created: 897
#
# Processing episode 106/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-106
#  → Tokens created: 1989
#
# Processing episode 107/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-107
#  → Tokens created: 2769
#
# Processing episode 108/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-108
#  → Tokens created: 5850
#
# Processing episode 109/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-109
#  → Tokens created: 897
#
# Processing episode 110/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-110
#  → Tokens created: 2769
#
# Processing episode 111/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-111
#  → Tokens created: 7371
#
# Processing episode 112/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-112
#  → Tokens created: 1989
#
# Processing episode 113/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-113
#  → Tokens created: 7293
#
# Processing episode 114/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-114
#  → Tokens created: 2730
#
# Processing episode 115/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-115
#  → Tokens created: 8385
#
# Processing episode 116/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-116
#  → Tokens created: 5889
#
# Processing episode 117/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-117
#  → Tokens created: 5967
#
# Processing episode 118/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-118
#  → Tokens created: 897
#
# Processing episode 119/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-119
#  → Tokens created: 897
#
# Processing episode 120/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-120
#  → Tokens created: 1989
#
# Processing episode 121/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-121
#  → Tokens created: 3861
#
# Processing episode 122/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-122
#  → Tokens created: 3822
#
# Processing episode 123/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-123
#  → Tokens created: 2769
#
# Processing episode 124/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-124
#  → Tokens created: 1989
#
# Processing episode 125/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-125
#  → Tokens created: 5031
#
# Processing episode 126/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-126
#  → Tokens created: 1989
#
# Processing episode 127/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-127
#  → Tokens created: 3354
#
# Processing episode 128/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-128
#  → Tokens created: 897
#
# Processing episode 129/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-129
#  → Tokens created: 4563
#
# Processing episode 130/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-130
#  → Tokens created: 3354
#
# Processing episode 131/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-131
#  → Tokens created: 2067
#
# Processing episode 132/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-132
#  → Tokens created: 2769
#
# Processing episode 133/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-133
#  → Tokens created: 4641
#
# Processing episode 134/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-134
#  → Tokens created: 6318
#
# Processing episode 135/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-135
#  → Tokens created: 6006
#
# Processing episode 136/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-136
#  → Tokens created: 897
#
# Processing episode 137/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-137
#  → Tokens created: 1989
#
# Processing episode 138/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-138
#  → Tokens created: 3276
#
# Processing episode 139/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-139
#  → Tokens created: 7410
#
# Processing episode 140/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-140
#  → Tokens created: 1989
#
# Processing episode 141/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-141
#  → Tokens created: 2769
#
# Processing episode 142/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-142
#  → Tokens created: 4719
#
# Processing episode 143/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-143
#  → Tokens created: 3354
#
# Processing episode 144/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-144
#  → Tokens created: 8385
#
# Processing episode 145/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-145
#  → Tokens created: 2769
#
# Processing episode 146/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-146
#  → Tokens created: 3354
#
# Processing episode 147/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-147
#  → Tokens created: 2691
#
# Processing episode 148/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-148
#  → Tokens created: 897
#
# Processing episode 149/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-149
#  → Tokens created: 1989
#
# Processing episode 150/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-150
#  → Tokens created: 6942
#
# Processing episode 151/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-151
#  → Tokens created: 3276
#
# Processing episode 152/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-152
#  → Tokens created: 3276
#
# Processing episode 153/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-153
#  → Tokens created: 897
#
# Processing episode 154/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-154
#  → Tokens created: 6045
#
# Processing episode 155/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-155
#  → Tokens created: 3354
#
# Processing episode 156/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-156
#  → Tokens created: 897
#
# Processing episode 157/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-157
#  → Tokens created: 5031
#
# Processing episode 158/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-158
#  → Tokens created: 897
#
# Processing episode 159/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-159
#  → Tokens created: 7410
#
# Processing episode 160/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-160
#  → Tokens created: 1989
#
# Processing episode 161/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-161
#  → Tokens created: 897
#
# Processing episode 162/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-162
#  → Tokens created: 3900
#
# Processing episode 163/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-163
#  → Tokens created: 11622
#
# Processing episode 164/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-164
#  → Tokens created: 897
#
# Processing episode 165/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-165
#  → Tokens created: 3822
#
# Processing episode 166/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-166
#  → Tokens created: 6474
#
# Processing episode 167/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-167
#  → Tokens created: 6864
#
# Processing episode 168/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-168
#  → Tokens created: 3354
#
# Processing episode 169/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-169
#  → Tokens created: 897
#
# Processing episode 170/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-170
#  → Tokens created: 1989
#
# Processing episode 171/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-171
#  → Tokens created: 2769
#
# Processing episode 172/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-172
#  → Tokens created: 1989
#
# Processing episode 173/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-173
#  → Tokens created: 3354
#
# Processing episode 174/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-174
#  → Tokens created: 5031
#
# Processing episode 175/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-175
#  → Tokens created: 897
#
# Processing episode 176/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-176
#  → Tokens created: 7644
#
# Processing episode 177/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-177
#  → Tokens created: 897
#
# Processing episode 178/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-178
#  → Tokens created: 15366
#
# Processing episode 179/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-179
#  → Tokens created: 8775
#
# Processing episode 180/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-180
#  → Tokens created: 1989
#
# Processing episode 181/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-181
#  → Tokens created: 3198
#
# Processing episode 182/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-182
#  → Tokens created: 3276
#
# Processing episode 183/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-183
#  → Tokens created: 2691
#
# Processing episode 184/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-184
#  → Tokens created: 897
#
# Processing episode 185/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-185
#  → Tokens created: 6708
#
# Processing episode 186/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-186
#  → Tokens created: 897
#
# Processing episode 187/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-187
#  → Tokens created: 1989
#
# Processing episode 188/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-188
#  → Tokens created: 7098
#
# Processing episode 189/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-189
#  → Tokens created: 897
#
# Processing episode 190/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-190
#  → Tokens created: 6669
#
# Processing episode 191/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-191
#  → Tokens created: 3354
#
# Processing episode 192/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-192
#  → Tokens created: 6396
#
# Processing episode 193/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-193
#  → Tokens created: 3354
#
# Processing episode 194/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-194
#  → Tokens created: 897
#
# Processing episode 195/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-195
#  → Tokens created: 3276
#
# Processing episode 196/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-196
#  → Tokens created: 2769
#
# Processing episode 197/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-197
#  → Tokens created: 2769
#
# Processing episode 198/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-198
#  → Tokens created: 1989
#
# Processing episode 199/199
# NPZ ↔ BreakoutNoFrameskip-v4-recorded_images-199
#  → Tokens created: 2769
#
# ======== PREPROCESSING COMPLETE ========
# Total episodes processed: 200
# Example episode #0 token count: 897

# %%
import pickle
from pathlib import Path
from npz_loader import discover_game_npz_paths, get_sequences_by_game, fix_obs_paths
from atari_preprocess import preprocess_one_sequence, find_image_folders

train_game_dirs = [
    Path("dataset/BeamRiderNoFrameskip-v4/BeamRiderNoFrameskip-v4"),
    Path("dataset/BreakoutNoFrameskip-v4/BreakoutNoFrameskip-v4"),
    Path("dataset/EnduroNoFrameskip-v4/EnduroNoFrameskip-v4"),
    Path("dataset/MsPacmanNoFrameskip-v4/MsPacmanNoFrameskip-v4"),
    Path("dataset/QbertNoFrameskip-v4/QbertNoFrameskip-v4"),
    Path("dataset/SeaquestNoFrameskip-v4/SeaquestNoFrameskip-v4"),
    Path("dataset/SpaceInvadersNoFrameskip-v4/SpaceInvadersNoFrameskip-v4"),
]

for game_root in train_game_dirs:

    # Load NPZ files
    npz_paths_by_game = discover_game_npz_paths([game_root])
    game_to_sequences = get_sequences_by_game(npz_paths_by_game)
    sequences_by_game = fix_obs_paths(game_to_sequences, dataset_root="dataset")

    game_key = list(sequences_by_game.keys())[0]
    npz_sequences = sequences_by_game[game_key]
    print(f"Found {len(npz_sequences)} NPZ sequences.")

    # Load image folders
    image_folders = find_image_folders(game_root)
    print(f"Found {len(image_folders)} image folders.")

    if len(image_folders) != len(npz_sequences):
        print("WARNING: NPZ count and image folder count differ!")

    # Preprocess & collect tokens for this game
    all_token_lists = []

    for idx, npz_seq in enumerate(npz_sequences):
        img_folder = image_folders[idx]
        print(f"\nProcessing episode {idx}/{len(npz_sequences)-1} — {img_folder.name}")

        tokens = preprocess_one_sequence(
            npz_seq=npz_seq,
            game_root=game_root,
            seq_index=idx
        )

        print(f" → Tokens created: {len(tokens)}")
        all_token_lists.append(tokens)

    print("\n======== PREPROCESSING COMPLETE ========")

    # Save tokens
    out_path = Path("token_outputs")
    out_path.mkdir(exist_ok=True)

    safe_game_key = str(game_key).replace("/", "_")   # <-- SIMPLE FIX

    pickle_file = out_path / f"{safe_game_key}_tokens.pkl"

    with open(pickle_file, "wb") as f:
        pickle.dump(all_token_lists, f)

    print(f"Saved token file → {pickle_file}")
    print("=====================================================\n")
# Out:
# Found 200 NPZ sequences.
# Found 200 image folders.
#
# Processing episode 0/199 — BeamRiderNoFrameskip-v4-recorded_images-0
#  → Tokens created: 21372
#
# Processing episode 1/199 — BeamRiderNoFrameskip-v4-recorded_images-1
#  → Tokens created: 14274
#
# Processing episode 2/199 — BeamRiderNoFrameskip-v4-recorded_images-2
#  → Tokens created: 21021
#
# Processing episode 3/199 — BeamRiderNoFrameskip-v4-recorded_images-3
#  → Tokens created: 17043
#
# Processing episode 4/199 — BeamRiderNoFrameskip-v4-recorded_images-4
#  → Tokens created: 20787
#
# Processing episode 5/199 — BeamRiderNoFrameskip-v4-recorded_images-5
#  → Tokens created: 18837
#
# Processing episode 6/199 — BeamRiderNoFrameskip-v4-recorded_images-6
#  → Tokens created: 20124
#
# Processing episode 7/199 — BeamRiderNoFrameskip-v4-recorded_images-7
#  → Tokens created: 32643
#
# Processing episode 8/199 — BeamRiderNoFrameskip-v4-recorded_images-8
#  → Tokens created: 18954
#
# Processing episode 9/199 — BeamRiderNoFrameskip-v4-recorded_images-9
#  → Tokens created: 22737
#
# Processing episode 10/199 — BeamRiderNoFrameskip-v4-recorded_images-10
#  → Tokens created: 36738
#
# Processing episode 11/199 — BeamRiderNoFrameskip-v4-recorded_images-11
#  → Tokens created: 21606
#
# Processing episode 12/199 — BeamRiderNoFrameskip-v4-recorded_images-12
#  → Tokens created: 21606
#
# Processing episode 13/199 — BeamRiderNoFrameskip-v4-recorded_images-13
#  → Tokens created: 14235
#
# Processing episode 14/199 — BeamRiderNoFrameskip-v4-recorded_images-14
#  → Tokens created: 17628
#
# Processing episode 15/199 — BeamRiderNoFrameskip-v4-recorded_images-15
#  → Tokens created: 17277
#
# Processing episode 16/199 — BeamRiderNoFrameskip-v4-recorded_images-16
#  → Tokens created: 27690
#
# Processing episode 17/199 — BeamRiderNoFrameskip-v4-recorded_images-17
#  → Tokens created: 18798
#
# Processing episode 18/199 — BeamRiderNoFrameskip-v4-recorded_images-18
#  → Tokens created: 18837
#
# Processing episode 19/199 — BeamRiderNoFrameskip-v4-recorded_images-19
#  → Tokens created: 22152
#
# Processing episode 20/199 — BeamRiderNoFrameskip-v4-recorded_images-20
#  → Tokens created: 28041
#
# Processing episode 21/199 — BeamRiderNoFrameskip-v4-recorded_images-21
#  → Tokens created: 20904
#
# Processing episode 22/199 — BeamRiderNoFrameskip-v4-recorded_images-22
#  → Tokens created: 20436
#
# Processing episode 23/199 — BeamRiderNoFrameskip-v4-recorded_images-23
#  → Tokens created: 14391
#
# Processing episode 24/199 — BeamRiderNoFrameskip-v4-recorded_images-24
#  → Tokens created: 16575
#
# Processing episode 25/199 — BeamRiderNoFrameskip-v4-recorded_images-25
#  → Tokens created: 34320
#
# Processing episode 26/199 — BeamRiderNoFrameskip-v4-recorded_images-26
#  → Tokens created: 28782
#
# Processing episode 27/199 — BeamRiderNoFrameskip-v4-recorded_images-27
#  → Tokens created: 15912
#
# Processing episode 28/199 — BeamRiderNoFrameskip-v4-recorded_images-28
#  → Tokens created: 15912
#
# Processing episode 29/199 — BeamRiderNoFrameskip-v4-recorded_images-29
#  → Tokens created: 21918
#
# Processing episode 30/199 — BeamRiderNoFrameskip-v4-recorded_images-30
#  → Tokens created: 17862
#
# Processing episode 31/199 — BeamRiderNoFrameskip-v4-recorded_images-31
#  → Tokens created: 15756
#
# Processing episode 32/199 — BeamRiderNoFrameskip-v4-recorded_images-32
#  → Tokens created: 17589
#
# Processing episode 33/199 — BeamRiderNoFrameskip-v4-recorded_images-33
#  → Tokens created: 35763
#
# Processing episode 34/199 — BeamRiderNoFrameskip-v4-recorded_images-34
#  → Tokens created: 21567
#
# Processing episode 35/199 — BeamRiderNoFrameskip-v4-recorded_images-35
#  → Tokens created: 32799
#
# Processing episode 36/199 — BeamRiderNoFrameskip-v4-recorded_images-36
#  → Tokens created: 16692
#
# Processing episode 37/199 — BeamRiderNoFrameskip-v4-recorded_images-37
#  → Tokens created: 21684
#
# Processing episode 38/199 — BeamRiderNoFrameskip-v4-recorded_images-38
#  → Tokens created: 17316
#
# Processing episode 39/199 — BeamRiderNoFrameskip-v4-recorded_images-39
#  → Tokens created: 27183
#
# Processing episode 40/199 — BeamRiderNoFrameskip-v4-recorded_images-40
#  → Tokens created: 18798
#
# Processing episode 41/199 — BeamRiderNoFrameskip-v4-recorded_images-41
#  → Tokens created: 40482
#
# Processing episode 42/199 — BeamRiderNoFrameskip-v4-recorded_images-42
#  → Tokens created: 25779
#
# Processing episode 43/199 — BeamRiderNoFrameskip-v4-recorded_images-43
#  → Tokens created: 18135
#
# Processing episode 44/199 — BeamRiderNoFrameskip-v4-recorded_images-44
#  → Tokens created: 14781
#
# Processing episode 45/199 — BeamRiderNoFrameskip-v4-recorded_images-45
#  → Tokens created: 29718
#
# Processing episode 46/199 — BeamRiderNoFrameskip-v4-recorded_images-46
#  → Tokens created: 20904
#
# Processing episode 47/199 — BeamRiderNoFrameskip-v4-recorded_images-47
#  → Tokens created: 21684
#
# Processing episode 48/199 — BeamRiderNoFrameskip-v4-recorded_images-48
#  → Tokens created: 15756
#
# Processing episode 49/199 — BeamRiderNoFrameskip-v4-recorded_images-49
#  → Tokens created: 12051
#
# Processing episode 50/199 — BeamRiderNoFrameskip-v4-recorded_images-50
#  → Tokens created: 12441
#
# Processing episode 51/199 — BeamRiderNoFrameskip-v4-recorded_images-51
#  → Tokens created: 29835
#
# Processing episode 52/199 — BeamRiderNoFrameskip-v4-recorded_images-52
#  → Tokens created: 26052
#
# Processing episode 53/199 — BeamRiderNoFrameskip-v4-recorded_images-53
#  → Tokens created: 19656
#
# Processing episode 54/199 — BeamRiderNoFrameskip-v4-recorded_images-54
#  → Tokens created: 17121
#
# Processing episode 55/199 — BeamRiderNoFrameskip-v4-recorded_images-55
#  → Tokens created: 23049
#
# Processing episode 56/199 — BeamRiderNoFrameskip-v4-recorded_images-56
#  → Tokens created: 18486
#
# Processing episode 57/199 — BeamRiderNoFrameskip-v4-recorded_images-57
#  → Tokens created: 27222
#
# Processing episode 58/199 — BeamRiderNoFrameskip-v4-recorded_images-58
#  → Tokens created: 18096
#
# Processing episode 59/199 — BeamRiderNoFrameskip-v4-recorded_images-59
#  → Tokens created: 15756
#
# Processing episode 60/199 — BeamRiderNoFrameskip-v4-recorded_images-60
#  → Tokens created: 17901
#
# Processing episode 61/199 — BeamRiderNoFrameskip-v4-recorded_images-61
#  → Tokens created: 26169
#
# Processing episode 62/199 — BeamRiderNoFrameskip-v4-recorded_images-62
#  → Tokens created: 24063
#
# Processing episode 63/199 — BeamRiderNoFrameskip-v4-recorded_images-63
#  → Tokens created: 13728
#
# Processing episode 64/199 — BeamRiderNoFrameskip-v4-recorded_images-64
#  → Tokens created: 22698
#
# Processing episode 65/199 — BeamRiderNoFrameskip-v4-recorded_images-65
#  → Tokens created: 12441
#
# Processing episode 66/199 — BeamRiderNoFrameskip-v4-recorded_images-66
#  → Tokens created: 20319
#
# Processing episode 67/199 — BeamRiderNoFrameskip-v4-recorded_images-67
#  → Tokens created: 21996
#
# Processing episode 68/199 — BeamRiderNoFrameskip-v4-recorded_images-68
#  → Tokens created: 17628
#
# Processing episode 69/199 — BeamRiderNoFrameskip-v4-recorded_images-69
#  → Tokens created: 23127
#
# Processing episode 70/199 — BeamRiderNoFrameskip-v4-recorded_images-70
#  → Tokens created: 14898
#
# Processing episode 71/199 — BeamRiderNoFrameskip-v4-recorded_images-71
#  → Tokens created: 20397
#
# Processing episode 72/199 — BeamRiderNoFrameskip-v4-recorded_images-72
#  → Tokens created: 17901
#
# Processing episode 73/199 — BeamRiderNoFrameskip-v4-recorded_images-73
#  → Tokens created: 16614
#
# Processing episode 74/199 — BeamRiderNoFrameskip-v4-recorded_images-74
#  → Tokens created: 26364
#
# Processing episode 75/199 — BeamRiderNoFrameskip-v4-recorded_images-75
#  → Tokens created: 13728
#
# Processing episode 76/199 — BeamRiderNoFrameskip-v4-recorded_images-76
#  → Tokens created: 17004
#
# Processing episode 77/199 — BeamRiderNoFrameskip-v4-recorded_images-77
#  → Tokens created: 16614
#
# Processing episode 78/199 — BeamRiderNoFrameskip-v4-recorded_images-78
#  → Tokens created: 22113
#
# Processing episode 79/199 — BeamRiderNoFrameskip-v4-recorded_images-79
#  → Tokens created: 66768
#
# Processing episode 80/199 — BeamRiderNoFrameskip-v4-recorded_images-80
#  → Tokens created: 20670
#
# Processing episode 81/199 — BeamRiderNoFrameskip-v4-recorded_images-81
#  → Tokens created: 21372
#
# Processing episode 82/199 — BeamRiderNoFrameskip-v4-recorded_images-82
#  → Tokens created: 18798
#
# Processing episode 83/199 — BeamRiderNoFrameskip-v4-recorded_images-83
#  → Tokens created: 26949
#
# Processing episode 84/199 — BeamRiderNoFrameskip-v4-recorded_images-84
#  → Tokens created: 28431
#
# Processing episode 85/199 — BeamRiderNoFrameskip-v4-recorded_images-85
#  → Tokens created: 11583
#
# Processing episode 86/199 — BeamRiderNoFrameskip-v4-recorded_images-86
#  → Tokens created: 27378
#
# Processing episode 87/199 — BeamRiderNoFrameskip-v4-recorded_images-87
#  → Tokens created: 31044
#
# Processing episode 88/199 — BeamRiderNoFrameskip-v4-recorded_images-88
#  → Tokens created: 12051
#
# Processing episode 89/199 — BeamRiderNoFrameskip-v4-recorded_images-89
#  → Tokens created: 25545
#
# Processing episode 90/199 — BeamRiderNoFrameskip-v4-recorded_images-90
#  → Tokens created: 19812
#
# Processing episode 91/199 — BeamRiderNoFrameskip-v4-recorded_images-91
#  → Tokens created: 21684
#
# Processing episode 92/199 — BeamRiderNoFrameskip-v4-recorded_images-92
#  → Tokens created: 24297
#
# Processing episode 93/199 — BeamRiderNoFrameskip-v4-recorded_images-93
#  → Tokens created: 20085
#
# Processing episode 94/199 — BeamRiderNoFrameskip-v4-recorded_images-94
#  → Tokens created: 13143
#
# Processing episode 95/199 — BeamRiderNoFrameskip-v4-recorded_images-95
#  → Tokens created: 31005
#
# Processing episode 96/199 — BeamRiderNoFrameskip-v4-recorded_images-96
#  → Tokens created: 14235
#
# Processing episode 97/199 — BeamRiderNoFrameskip-v4-recorded_images-97
#  → Tokens created: 17784
#
# Processing episode 98/199 — BeamRiderNoFrameskip-v4-recorded_images-98
#  → Tokens created: 15834
#
# Processing episode 99/199 — BeamRiderNoFrameskip-v4-recorded_images-99
#  → Tokens created: 21528
#
# Processing episode 100/199 — BeamRiderNoFrameskip-v4-recorded_images-100
#  → Tokens created: 22074
#
# Processing episode 101/199 — BeamRiderNoFrameskip-v4-recorded_images-101
#  → Tokens created: 17784
#
# Processing episode 102/199 — BeamRiderNoFrameskip-v4-recorded_images-102
#  → Tokens created: 21684
#
# Processing episode 103/199 — BeamRiderNoFrameskip-v4-recorded_images-103
#  → Tokens created: 21021
#
# Processing episode 104/199 — BeamRiderNoFrameskip-v4-recorded_images-104
#  → Tokens created: 24297
#
# Processing episode 105/199 — BeamRiderNoFrameskip-v4-recorded_images-105
#  → Tokens created: 39507
#
# Processing episode 106/199 — BeamRiderNoFrameskip-v4-recorded_images-106
#  → Tokens created: 31551
#
# Processing episode 107/199 — BeamRiderNoFrameskip-v4-recorded_images-107
#  → Tokens created: 28587
#
# Processing episode 108/199 — BeamRiderNoFrameskip-v4-recorded_images-108
#  → Tokens created: 18915
#
# Processing episode 109/199 — BeamRiderNoFrameskip-v4-recorded_images-109
#  → Tokens created: 22464
#
# Processing episode 110/199 — BeamRiderNoFrameskip-v4-recorded_images-110
#  → Tokens created: 19578
#
# Processing episode 111/199 — BeamRiderNoFrameskip-v4-recorded_images-111
#  → Tokens created: 37986
#
# Processing episode 112/199 — BeamRiderNoFrameskip-v4-recorded_images-112
#  → Tokens created: 38376
#
# Processing episode 113/199 — BeamRiderNoFrameskip-v4-recorded_images-113
#  → Tokens created: 17862
#
# Processing episode 114/199 — BeamRiderNoFrameskip-v4-recorded_images-114
#  → Tokens created: 31551
#
# Processing episode 115/199 — BeamRiderNoFrameskip-v4-recorded_images-115
#  → Tokens created: 21528
#
# Processing episode 116/199 — BeamRiderNoFrameskip-v4-recorded_images-116
#  → Tokens created: 17862
#
# Processing episode 117/199 — BeamRiderNoFrameskip-v4-recorded_images-117
#  → Tokens created: 28431
#
# Processing episode 118/199 — BeamRiderNoFrameskip-v4-recorded_images-118
#  → Tokens created: 21372
#
# Processing episode 119/199 — BeamRiderNoFrameskip-v4-recorded_images-119
#  → Tokens created: 14274
#
# Processing episode 120/199 — BeamRiderNoFrameskip-v4-recorded_images-120
#  → Tokens created: 11583
#
# Processing episode 121/199 — BeamRiderNoFrameskip-v4-recorded_images-121
#  → Tokens created: 18486
#
# Processing episode 122/199 — BeamRiderNoFrameskip-v4-recorded_images-122
#  → Tokens created: 17628
#
# Processing episode 123/199 — BeamRiderNoFrameskip-v4-recorded_images-123
#  → Tokens created: 20904
#
# Processing episode 124/199 — BeamRiderNoFrameskip-v4-recorded_images-124
#  → Tokens created: 23517
#
# Processing episode 125/199 — BeamRiderNoFrameskip-v4-recorded_images-125
#  → Tokens created: 18798
#
# Processing episode 126/199 — BeamRiderNoFrameskip-v4-recorded_images-126
#  → Tokens created: 26364
#
# Processing episode 127/199 — BeamRiderNoFrameskip-v4-recorded_images-127
#  → Tokens created: 22659
#
# Processing episode 128/199 — BeamRiderNoFrameskip-v4-recorded_images-128
#  → Tokens created: 19578
#
# Processing episode 129/199 — BeamRiderNoFrameskip-v4-recorded_images-129
#  → Tokens created: 25779
#
# Processing episode 130/199 — BeamRiderNoFrameskip-v4-recorded_images-130
#  → Tokens created: 25428
#
# Processing episode 131/199 — BeamRiderNoFrameskip-v4-recorded_images-131
#  → Tokens created: 31395
#
# Processing episode 132/199 — BeamRiderNoFrameskip-v4-recorded_images-132
#  → Tokens created: 20046
#
# Processing episode 133/199 — BeamRiderNoFrameskip-v4-recorded_images-133
#  → Tokens created: 20787
#
# Processing episode 134/199 — BeamRiderNoFrameskip-v4-recorded_images-134
#  → Tokens created: 19656
#
# Processing episode 135/199 — BeamRiderNoFrameskip-v4-recorded_images-135
#  → Tokens created: 13143
#
# Processing episode 136/199 — BeamRiderNoFrameskip-v4-recorded_images-136
#  → Tokens created: 14898
#
# Processing episode 137/199 — BeamRiderNoFrameskip-v4-recorded_images-137
#  → Tokens created: 34281
#
# Processing episode 138/199 — BeamRiderNoFrameskip-v4-recorded_images-138
#  → Tokens created: 28041
#
# Processing episode 139/199 — BeamRiderNoFrameskip-v4-recorded_images-139
#  → Tokens created: 19578
#
# Processing episode 140/199 — BeamRiderNoFrameskip-v4-recorded_images-140
#  → Tokens created: 17628
#
# Processing episode 141/199 — BeamRiderNoFrameskip-v4-recorded_images-141
#  → Tokens created: 34788
#
# Processing episode 142/199 — BeamRiderNoFrameskip-v4-recorded_images-142
#  → Tokens created: 20670
#
# Processing episode 143/199 — BeamRiderNoFrameskip-v4-recorded_images-143
#  → Tokens created: 28392
#
# Processing episode 144/199 — BeamRiderNoFrameskip-v4-recorded_images-144
#  → Tokens created: 32799
#
# Processing episode 145/199 — BeamRiderNoFrameskip-v4-recorded_images-145
#  → Tokens created: 23127
#
# Processing episode 146/199 — BeamRiderNoFrameskip-v4-recorded_images-146
#  → Tokens created: 17316
#
# Processing episode 147/199 — BeamRiderNoFrameskip-v4-recorded_images-147
#  → Tokens created: 14235
#
# Processing episode 148/199 — BeamRiderNoFrameskip-v4-recorded_images-148
#  → Tokens created: 20124
#
# Processing episode 149/199 — BeamRiderNoFrameskip-v4-recorded_images-149
#  → Tokens created: 32643
#
# Processing episode 150/199 — BeamRiderNoFrameskip-v4-recorded_images-150
#  → Tokens created: 20826
#
# Processing episode 151/199 — BeamRiderNoFrameskip-v4-recorded_images-151
#  → Tokens created: 16575
#
# Processing episode 152/199 — BeamRiderNoFrameskip-v4-recorded_images-152
#  → Tokens created: 27183
#
# Processing episode 153/199 — BeamRiderNoFrameskip-v4-recorded_images-153
#  → Tokens created: 19578
#
# Processing episode 154/199 — BeamRiderNoFrameskip-v4-recorded_images-154
#  → Tokens created: 14235
#
# Processing episode 155/199 — BeamRiderNoFrameskip-v4-recorded_images-155
#  → Tokens created: 32331
#
# Processing episode 156/199 — BeamRiderNoFrameskip-v4-recorded_images-156
#  → Tokens created: 20358
#
# Processing episode 157/199 — BeamRiderNoFrameskip-v4-recorded_images-157
#  → Tokens created: 36543
#
# Processing episode 158/199 — BeamRiderNoFrameskip-v4-recorded_images-158
#  → Tokens created: 24336
#
# Processing episode 159/199 — BeamRiderNoFrameskip-v4-recorded_images-159
#  → Tokens created: 67431
#
# Processing episode 160/199 — BeamRiderNoFrameskip-v4-recorded_images-160
#  → Tokens created: 19305
#
# Processing episode 161/199 — BeamRiderNoFrameskip-v4-recorded_images-161
#  → Tokens created: 17277
#
# Processing episode 162/199 — BeamRiderNoFrameskip-v4-recorded_images-162
#  → Tokens created: 31239
#
# Processing episode 163/199 — BeamRiderNoFrameskip-v4-recorded_images-163
#  → Tokens created: 22464
#
# Processing episode 164/199 — BeamRiderNoFrameskip-v4-recorded_images-164
#  → Tokens created: 20241
#
# Processing episode 165/199 — BeamRiderNoFrameskip-v4-recorded_images-165
#  → Tokens created: 30576
#
# Processing episode 166/199 — BeamRiderNoFrameskip-v4-recorded_images-166
#  → Tokens created: 17823
#
# Processing episode 167/199 — BeamRiderNoFrameskip-v4-recorded_images-167
#  → Tokens created: 19305
#
# Processing episode 168/199 — BeamRiderNoFrameskip-v4-recorded_images-168
#  → Tokens created: 36699
#
# Processing episode 169/199 — BeamRiderNoFrameskip-v4-recorded_images-169
#  → Tokens created: 14391
#
# Processing episode 170/199 — BeamRiderNoFrameskip-v4-recorded_images-170
#  → Tokens created: 45513
#
# Processing episode 171/199 — BeamRiderNoFrameskip-v4-recorded_images-171
#  → Tokens created: 28041
#
# Processing episode 172/199 — BeamRiderNoFrameskip-v4-recorded_images-172
#  → Tokens created: 23439
#
# Processing episode 173/199 — BeamRiderNoFrameskip-v4-recorded_images-173
#  → Tokens created: 17277
#
# Processing episode 174/199 — BeamRiderNoFrameskip-v4-recorded_images-174
#  → Tokens created: 19305
#
# Processing episode 175/199 — BeamRiderNoFrameskip-v4-recorded_images-175
#  → Tokens created: 28431
#
# Processing episode 176/199 — BeamRiderNoFrameskip-v4-recorded_images-176
#  → Tokens created: 21060
#
# Processing episode 177/199 — BeamRiderNoFrameskip-v4-recorded_images-177
#  → Tokens created: 15756
#
# Processing episode 178/199 — BeamRiderNoFrameskip-v4-recorded_images-178
#  → Tokens created: 22152
#
# Processing episode 179/199 — BeamRiderNoFrameskip-v4-recorded_images-179
#  → Tokens created: 23127
#
# Processing episode 180/199 — BeamRiderNoFrameskip-v4-recorded_images-180
#  → Tokens created: 17043
#
# Processing episode 181/199 — BeamRiderNoFrameskip-v4-recorded_images-181
#  → Tokens created: 22464
#
# Processing episode 182/199 — BeamRiderNoFrameskip-v4-recorded_images-182
#  → Tokens created: 19032
#
# Processing episode 183/199 — BeamRiderNoFrameskip-v4-recorded_images-183
#  → Tokens created: 20904
#
# Processing episode 184/199 — BeamRiderNoFrameskip-v4-recorded_images-184
#  → Tokens created: 14781
#
# Processing episode 185/199 — BeamRiderNoFrameskip-v4-recorded_images-185
#  → Tokens created: 40482
#
# Processing episode 186/199 — BeamRiderNoFrameskip-v4-recorded_images-186
#  → Tokens created: 17862
#
# Processing episode 187/199 — BeamRiderNoFrameskip-v4-recorded_images-187
#  → Tokens created: 24648
#
# Processing episode 188/199 — BeamRiderNoFrameskip-v4-recorded_images-188
#  → Tokens created: 21567
#
# Processing episode 189/199 — BeamRiderNoFrameskip-v4-recorded_images-189
#  → Tokens created: 28041
#
# Processing episode 190/199 — BeamRiderNoFrameskip-v4-recorded_images-190
#  → Tokens created: 19305
#
# Processing episode 191/199 — BeamRiderNoFrameskip-v4-recorded_images-191
#  → Tokens created: 20436
#
# Processing episode 192/199 — BeamRiderNoFrameskip-v4-recorded_images-192
#  → Tokens created: 19149
#
# Processing episode 193/199 — BeamRiderNoFrameskip-v4-recorded_images-193
#  → Tokens created: 16692
#
# Processing episode 194/199 — BeamRiderNoFrameskip-v4-recorded_images-194
#  → Tokens created: 17823
#
# Processing episode 195/199 — BeamRiderNoFrameskip-v4-recorded_images-195
#  → Tokens created: 18837
#
# Processing episode 196/199 — BeamRiderNoFrameskip-v4-recorded_images-196
#  → Tokens created: 18837
#
# Processing episode 197/199 — BeamRiderNoFrameskip-v4-recorded_images-197
#  → Tokens created: 17277
#
# Processing episode 198/199 — BeamRiderNoFrameskip-v4-recorded_images-198
#  → Tokens created: 15951
#
# Processing episode 199/199 — BeamRiderNoFrameskip-v4-recorded_images-199
#  → Tokens created: 17823
#
# ======== PREPROCESSING COMPLETE ========
# Saved token file → token_outputs/dataset_BeamRiderNoFrameskip-v4_BeamRiderNoFrameskip-v4_tokens.pkl
# =====================================================
#
# Found 200 NPZ sequences.
# Found 200 image folders.
#
# Processing episode 0/199 — BreakoutNoFrameskip-v4-recorded_images-0
#  → Tokens created: 897
#
# Processing episode 1/199 — BreakoutNoFrameskip-v4-recorded_images-1
#  → Tokens created: 3354
#
# Processing episode 2/199 — BreakoutNoFrameskip-v4-recorded_images-2
#  → Tokens created: 897
#
# Processing episode 3/199 — BreakoutNoFrameskip-v4-recorded_images-3
#  → Tokens created: 4719
#
# Processing episode 4/199 — BreakoutNoFrameskip-v4-recorded_images-4
#  → Tokens created: 5265
#
# Processing episode 5/199 — BreakoutNoFrameskip-v4-recorded_images-5
#  → Tokens created: 2769
#
# Processing episode 6/199 — BreakoutNoFrameskip-v4-recorded_images-6
#  → Tokens created: 1989
#
# Processing episode 7/199 — BreakoutNoFrameskip-v4-recorded_images-7
#  → Tokens created: 2769
#
# Processing episode 8/199 — BreakoutNoFrameskip-v4-recorded_images-8
#  → Tokens created: 5772
#
# Processing episode 9/199 — BreakoutNoFrameskip-v4-recorded_images-9
#  → Tokens created: 1989
#
# Processing episode 10/199 — BreakoutNoFrameskip-v4-recorded_images-10
#  → Tokens created: 3354
#
# Processing episode 11/199 — BreakoutNoFrameskip-v4-recorded_images-11
#  → Tokens created: 3354
#
# Processing episode 12/199 — BreakoutNoFrameskip-v4-recorded_images-12
#  → Tokens created: 3900
#
# Processing episode 13/199 — BreakoutNoFrameskip-v4-recorded_images-13
#  → Tokens created: 6786
#
# Processing episode 14/199 — BreakoutNoFrameskip-v4-recorded_images-14
#  → Tokens created: 3276
#
# Processing episode 15/199 — BreakoutNoFrameskip-v4-recorded_images-15
#  → Tokens created: 897
#
# Processing episode 16/199 — BreakoutNoFrameskip-v4-recorded_images-16
#  → Tokens created: 3354
#
# Processing episode 17/199 — BreakoutNoFrameskip-v4-recorded_images-17
#  → Tokens created: 6708
#
# Processing episode 18/199 — BreakoutNoFrameskip-v4-recorded_images-18
#  → Tokens created: 897
#
# Processing episode 19/199 — BreakoutNoFrameskip-v4-recorded_images-19
#  → Tokens created: 3822
#
# Processing episode 20/199 — BreakoutNoFrameskip-v4-recorded_images-20
#  → Tokens created: 5031
#
# Processing episode 21/199 — BreakoutNoFrameskip-v4-recorded_images-21
#  → Tokens created: 1989
#
# Processing episode 22/199 — BreakoutNoFrameskip-v4-recorded_images-22
#  → Tokens created: 897
#
# Processing episode 23/199 — BreakoutNoFrameskip-v4-recorded_images-23
#  → Tokens created: 897
#
# Processing episode 24/199 — BreakoutNoFrameskip-v4-recorded_images-24
#  → Tokens created: 1989
#
# Processing episode 25/199 — BreakoutNoFrameskip-v4-recorded_images-25
#  → Tokens created: 1989
#
# Processing episode 26/199 — BreakoutNoFrameskip-v4-recorded_images-26
#  → Tokens created: 3354
#
# Processing episode 27/199 — BreakoutNoFrameskip-v4-recorded_images-27
#  → Tokens created: 7683
#
# Processing episode 28/199 — BreakoutNoFrameskip-v4-recorded_images-28
#  → Tokens created: 2691
#
# Processing episode 29/199 — BreakoutNoFrameskip-v4-recorded_images-29
#  → Tokens created: 4563
#
# Processing episode 30/199 — BreakoutNoFrameskip-v4-recorded_images-30
#  → Tokens created: 6318
#
# Processing episode 31/199 — BreakoutNoFrameskip-v4-recorded_images-31
#  → Tokens created: 2730
#
# Processing episode 32/199 — BreakoutNoFrameskip-v4-recorded_images-32
#  → Tokens created: 1989
#
# Processing episode 33/199 — BreakoutNoFrameskip-v4-recorded_images-33
#  → Tokens created: 3861
#
# Processing episode 34/199 — BreakoutNoFrameskip-v4-recorded_images-34
#  → Tokens created: 7605
#
# Processing episode 35/199 — BreakoutNoFrameskip-v4-recorded_images-35
#  → Tokens created: 2769
#
# Processing episode 36/199 — BreakoutNoFrameskip-v4-recorded_images-36
#  → Tokens created: 2769
#
# Processing episode 37/199 — BreakoutNoFrameskip-v4-recorded_images-37
#  → Tokens created: 7839
#
# Processing episode 38/199 — BreakoutNoFrameskip-v4-recorded_images-38
#  → Tokens created: 3276
#
# Processing episode 39/199 — BreakoutNoFrameskip-v4-recorded_images-39
#  → Tokens created: 4641
#
# Processing episode 40/199 — BreakoutNoFrameskip-v4-recorded_images-40
#  → Tokens created: 8268
#
# Processing episode 41/199 — BreakoutNoFrameskip-v4-recorded_images-41
#  → Tokens created: 3276
#
# Processing episode 42/199 — BreakoutNoFrameskip-v4-recorded_images-42
#  → Tokens created: 7332
#
# Processing episode 43/199 — BreakoutNoFrameskip-v4-recorded_images-43
#  → Tokens created: 897
#
# Processing episode 44/199 — BreakoutNoFrameskip-v4-recorded_images-44
#  → Tokens created: 3276
#
# Processing episode 45/199 — BreakoutNoFrameskip-v4-recorded_images-45
#  → Tokens created: 8736
#
# Processing episode 46/199 — BreakoutNoFrameskip-v4-recorded_images-46
#  → Tokens created: 7644
#
# Processing episode 47/199 — BreakoutNoFrameskip-v4-recorded_images-47
#  → Tokens created: 897
#
# Processing episode 48/199 — BreakoutNoFrameskip-v4-recorded_images-48
#  → Tokens created: 897
#
# Processing episode 49/199 — BreakoutNoFrameskip-v4-recorded_images-49
#  → Tokens created: 10725
#
# Processing episode 50/199 — BreakoutNoFrameskip-v4-recorded_images-50
#  → Tokens created: 2769
#
# Processing episode 51/199 — BreakoutNoFrameskip-v4-recorded_images-51
#  → Tokens created: 1989
#
# Processing episode 52/199 — BreakoutNoFrameskip-v4-recorded_images-52
#  → Tokens created: 2769
#
# Processing episode 53/199 — BreakoutNoFrameskip-v4-recorded_images-53
#  → Tokens created: 2769
#
# Processing episode 54/199 — BreakoutNoFrameskip-v4-recorded_images-54
#  → Tokens created: 6045
#
# Processing episode 55/199 — BreakoutNoFrameskip-v4-recorded_images-55
#  → Tokens created: 2691
#
# Processing episode 56/199 — BreakoutNoFrameskip-v4-recorded_images-56
#  → Tokens created: 7332
#
# Processing episode 57/199 — BreakoutNoFrameskip-v4-recorded_images-57
#  → Tokens created: 1989
#
# Processing episode 58/199 — BreakoutNoFrameskip-v4-recorded_images-58
#  → Tokens created: 8580
#
# Processing episode 59/199 — BreakoutNoFrameskip-v4-recorded_images-59
#  → Tokens created: 3861
#
# Processing episode 60/199 — BreakoutNoFrameskip-v4-recorded_images-60
#  → Tokens created: 1989
#
# Processing episode 61/199 — BreakoutNoFrameskip-v4-recorded_images-61
#  → Tokens created: 6552
#
# Processing episode 62/199 — BreakoutNoFrameskip-v4-recorded_images-62
#  → Tokens created: 2769
#
# Processing episode 63/199 — BreakoutNoFrameskip-v4-recorded_images-63
#  → Tokens created: 5772
#
# Processing episode 64/199 — BreakoutNoFrameskip-v4-recorded_images-64
#  → Tokens created: 6630
#
# Processing episode 65/199 — BreakoutNoFrameskip-v4-recorded_images-65
#  → Tokens created: 897
#
# Processing episode 66/199 — BreakoutNoFrameskip-v4-recorded_images-66
#  → Tokens created: 6591
#
# Processing episode 67/199 — BreakoutNoFrameskip-v4-recorded_images-67
#  → Tokens created: 9243
#
# Processing episode 68/199 — BreakoutNoFrameskip-v4-recorded_images-68
#  → Tokens created: 6084
#
# Processing episode 69/199 — BreakoutNoFrameskip-v4-recorded_images-69
#  → Tokens created: 8580
#
# Processing episode 70/199 — BreakoutNoFrameskip-v4-recorded_images-70
#  → Tokens created: 1989
#
# Processing episode 71/199 — BreakoutNoFrameskip-v4-recorded_images-71
#  → Tokens created: 2769
#
# Processing episode 72/199 — BreakoutNoFrameskip-v4-recorded_images-72
#  → Tokens created: 897
#
# Processing episode 73/199 — BreakoutNoFrameskip-v4-recorded_images-73
#  → Tokens created: 3276
#
# Processing episode 74/199 — BreakoutNoFrameskip-v4-recorded_images-74
#  → Tokens created: 897
#
# Processing episode 75/199 — BreakoutNoFrameskip-v4-recorded_images-75
#  → Tokens created: 6396
#
# Processing episode 76/199 — BreakoutNoFrameskip-v4-recorded_images-76
#  → Tokens created: 897
#
# Processing episode 77/199 — BreakoutNoFrameskip-v4-recorded_images-77
#  → Tokens created: 897
#
# Processing episode 78/199 — BreakoutNoFrameskip-v4-recorded_images-78
#  → Tokens created: 1989
#
# Processing episode 79/199 — BreakoutNoFrameskip-v4-recorded_images-79
#  → Tokens created: 3354
#
# Processing episode 80/199 — BreakoutNoFrameskip-v4-recorded_images-80
#  → Tokens created: 4641
#
# Processing episode 81/199 — BreakoutNoFrameskip-v4-recorded_images-81
#  → Tokens created: 1989
#
# Processing episode 82/199 — BreakoutNoFrameskip-v4-recorded_images-82
#  → Tokens created: 5031
#
# Processing episode 83/199 — BreakoutNoFrameskip-v4-recorded_images-83
#  → Tokens created: 7605
#
# Processing episode 84/199 — BreakoutNoFrameskip-v4-recorded_images-84
#  → Tokens created: 5967
#
# Processing episode 85/199 — BreakoutNoFrameskip-v4-recorded_images-85
#  → Tokens created: 897
#
# Processing episode 86/199 — BreakoutNoFrameskip-v4-recorded_images-86
#  → Tokens created: 6591
#
# Processing episode 87/199 — BreakoutNoFrameskip-v4-recorded_images-87
#  → Tokens created: 3276
#
# Processing episode 88/199 — BreakoutNoFrameskip-v4-recorded_images-88
#  → Tokens created: 2769
#
# Processing episode 89/199 — BreakoutNoFrameskip-v4-recorded_images-89
#  → Tokens created: 1989
#
# Processing episode 90/199 — BreakoutNoFrameskip-v4-recorded_images-90
#  → Tokens created: 3900
#
# Processing episode 91/199 — BreakoutNoFrameskip-v4-recorded_images-91
#  → Tokens created: 3276
#
# Processing episode 92/199 — BreakoutNoFrameskip-v4-recorded_images-92
#  → Tokens created: 1989
#
# Processing episode 93/199 — BreakoutNoFrameskip-v4-recorded_images-93
#  → Tokens created: 3354
#
# Processing episode 94/199 — BreakoutNoFrameskip-v4-recorded_images-94
#  → Tokens created: 1989
#
# Processing episode 95/199 — BreakoutNoFrameskip-v4-recorded_images-95
#  → Tokens created: 897
#
# Processing episode 96/199 — BreakoutNoFrameskip-v4-recorded_images-96
#  → Tokens created: 6864
#
# Processing episode 97/199 — BreakoutNoFrameskip-v4-recorded_images-97
#  → Tokens created: 2769
#
# Processing episode 98/199 — BreakoutNoFrameskip-v4-recorded_images-98
#  → Tokens created: 3861
#
# Processing episode 99/199 — BreakoutNoFrameskip-v4-recorded_images-99
#  → Tokens created: 3354
#
# Processing episode 100/199 — BreakoutNoFrameskip-v4-recorded_images-100
#  → Tokens created: 1989
#
# Processing episode 101/199 — BreakoutNoFrameskip-v4-recorded_images-101
#  → Tokens created: 3276
#
# Processing episode 102/199 — BreakoutNoFrameskip-v4-recorded_images-102
#  → Tokens created: 897
#
# Processing episode 103/199 — BreakoutNoFrameskip-v4-recorded_images-103
#  → Tokens created: 2691
#
# Processing episode 104/199 — BreakoutNoFrameskip-v4-recorded_images-104
#  → Tokens created: 2769
#
# Processing episode 105/199 — BreakoutNoFrameskip-v4-recorded_images-105
#  → Tokens created: 897
#
# Processing episode 106/199 — BreakoutNoFrameskip-v4-recorded_images-106
#  → Tokens created: 1989
#
# Processing episode 107/199 — BreakoutNoFrameskip-v4-recorded_images-107
#  → Tokens created: 2769
#
# Processing episode 108/199 — BreakoutNoFrameskip-v4-recorded_images-108
#  → Tokens created: 5850
#
# Processing episode 109/199 — BreakoutNoFrameskip-v4-recorded_images-109
#  → Tokens created: 897
#
# Processing episode 110/199 — BreakoutNoFrameskip-v4-recorded_images-110
#  → Tokens created: 2769
#
# Processing episode 111/199 — BreakoutNoFrameskip-v4-recorded_images-111
#  → Tokens created: 7371
#
# Processing episode 112/199 — BreakoutNoFrameskip-v4-recorded_images-112
#  → Tokens created: 1989
#
# Processing episode 113/199 — BreakoutNoFrameskip-v4-recorded_images-113
#  → Tokens created: 7293
#
# Processing episode 114/199 — BreakoutNoFrameskip-v4-recorded_images-114
#  → Tokens created: 2730
#
# Processing episode 115/199 — BreakoutNoFrameskip-v4-recorded_images-115
#  → Tokens created: 8385
#
# Processing episode 116/199 — BreakoutNoFrameskip-v4-recorded_images-116
#  → Tokens created: 5889
#
# Processing episode 117/199 — BreakoutNoFrameskip-v4-recorded_images-117
#  → Tokens created: 5967
#
# Processing episode 118/199 — BreakoutNoFrameskip-v4-recorded_images-118
#  → Tokens created: 897
#
# Processing episode 119/199 — BreakoutNoFrameskip-v4-recorded_images-119
#  → Tokens created: 897
#
# Processing episode 120/199 — BreakoutNoFrameskip-v4-recorded_images-120
#  → Tokens created: 1989
#
# Processing episode 121/199 — BreakoutNoFrameskip-v4-recorded_images-121
#  → Tokens created: 3861
#
# Processing episode 122/199 — BreakoutNoFrameskip-v4-recorded_images-122
#  → Tokens created: 3822
#
# Processing episode 123/199 — BreakoutNoFrameskip-v4-recorded_images-123
#  → Tokens created: 2769
#
# Processing episode 124/199 — BreakoutNoFrameskip-v4-recorded_images-124
#  → Tokens created: 1989
#
# Processing episode 125/199 — BreakoutNoFrameskip-v4-recorded_images-125
#  → Tokens created: 5031
#
# Processing episode 126/199 — BreakoutNoFrameskip-v4-recorded_images-126
#  → Tokens created: 1989
#
# Processing episode 127/199 — BreakoutNoFrameskip-v4-recorded_images-127
#  → Tokens created: 3354
#
# Processing episode 128/199 — BreakoutNoFrameskip-v4-recorded_images-128
#  → Tokens created: 897
#
# Processing episode 129/199 — BreakoutNoFrameskip-v4-recorded_images-129
#  → Tokens created: 4563
#
# Processing episode 130/199 — BreakoutNoFrameskip-v4-recorded_images-130
#  → Tokens created: 3354
#
# Processing episode 131/199 — BreakoutNoFrameskip-v4-recorded_images-131
#  → Tokens created: 2067
#
# Processing episode 132/199 — BreakoutNoFrameskip-v4-recorded_images-132
#  → Tokens created: 2769
#
# Processing episode 133/199 — BreakoutNoFrameskip-v4-recorded_images-133
#  → Tokens created: 4641
#
# Processing episode 134/199 — BreakoutNoFrameskip-v4-recorded_images-134
#  → Tokens created: 6318
#
# Processing episode 135/199 — BreakoutNoFrameskip-v4-recorded_images-135
#  → Tokens created: 6006
#
# Processing episode 136/199 — BreakoutNoFrameskip-v4-recorded_images-136
#  → Tokens created: 897
#
# Processing episode 137/199 — BreakoutNoFrameskip-v4-recorded_images-137
#  → Tokens created: 1989
#
# Processing episode 138/199 — BreakoutNoFrameskip-v4-recorded_images-138
#  → Tokens created: 3276
#
# Processing episode 139/199 — BreakoutNoFrameskip-v4-recorded_images-139
#  → Tokens created: 7410
#
# Processing episode 140/199 — BreakoutNoFrameskip-v4-recorded_images-140
#  → Tokens created: 1989
#
# Processing episode 141/199 — BreakoutNoFrameskip-v4-recorded_images-141
#  → Tokens created: 2769
#
# Processing episode 142/199 — BreakoutNoFrameskip-v4-recorded_images-142
#  → Tokens created: 4719
#
# Processing episode 143/199 — BreakoutNoFrameskip-v4-recorded_images-143
#  → Tokens created: 3354
#
# Processing episode 144/199 — BreakoutNoFrameskip-v4-recorded_images-144
#  → Tokens created: 8385
#
# Processing episode 145/199 — BreakoutNoFrameskip-v4-recorded_images-145
#  → Tokens created: 2769
#
# Processing episode 146/199 — BreakoutNoFrameskip-v4-recorded_images-146
#  → Tokens created: 3354
#
# Processing episode 147/199 — BreakoutNoFrameskip-v4-recorded_images-147
#  → Tokens created: 2691
#
# Processing episode 148/199 — BreakoutNoFrameskip-v4-recorded_images-148
#  → Tokens created: 897
#
# Processing episode 149/199 — BreakoutNoFrameskip-v4-recorded_images-149
#  → Tokens created: 1989
#
# Processing episode 150/199 — BreakoutNoFrameskip-v4-recorded_images-150
#  → Tokens created: 6942
#
# Processing episode 151/199 — BreakoutNoFrameskip-v4-recorded_images-151
#  → Tokens created: 3276
#
# Processing episode 152/199 — BreakoutNoFrameskip-v4-recorded_images-152
#  → Tokens created: 3276
#
# Processing episode 153/199 — BreakoutNoFrameskip-v4-recorded_images-153
#  → Tokens created: 897
#
# Processing episode 154/199 — BreakoutNoFrameskip-v4-recorded_images-154
#  → Tokens created: 6045
#
# Processing episode 155/199 — BreakoutNoFrameskip-v4-recorded_images-155
#  → Tokens created: 3354
#
# Processing episode 156/199 — BreakoutNoFrameskip-v4-recorded_images-156
#  → Tokens created: 897
#
# Processing episode 157/199 — BreakoutNoFrameskip-v4-recorded_images-157
#  → Tokens created: 5031
#
# Processing episode 158/199 — BreakoutNoFrameskip-v4-recorded_images-158
#  → Tokens created: 897
#
# Processing episode 159/199 — BreakoutNoFrameskip-v4-recorded_images-159
#  → Tokens created: 7410
#
# Processing episode 160/199 — BreakoutNoFrameskip-v4-recorded_images-160
#  → Tokens created: 1989
#
# Processing episode 161/199 — BreakoutNoFrameskip-v4-recorded_images-161
#  → Tokens created: 897
#
# Processing episode 162/199 — BreakoutNoFrameskip-v4-recorded_images-162
#  → Tokens created: 3900
#
# Processing episode 163/199 — BreakoutNoFrameskip-v4-recorded_images-163
#  → Tokens created: 11622
#
# Processing episode 164/199 — BreakoutNoFrameskip-v4-recorded_images-164
#  → Tokens created: 897
#
# Processing episode 165/199 — BreakoutNoFrameskip-v4-recorded_images-165
#  → Tokens created: 3822
#
# Processing episode 166/199 — BreakoutNoFrameskip-v4-recorded_images-166
#  → Tokens created: 6474
#
# Processing episode 167/199 — BreakoutNoFrameskip-v4-recorded_images-167
#  → Tokens created: 6864
#
# Processing episode 168/199 — BreakoutNoFrameskip-v4-recorded_images-168
#  → Tokens created: 3354
#
# Processing episode 169/199 — BreakoutNoFrameskip-v4-recorded_images-169
#  → Tokens created: 897
#
# Processing episode 170/199 — BreakoutNoFrameskip-v4-recorded_images-170
#  → Tokens created: 1989
#
# Processing episode 171/199 — BreakoutNoFrameskip-v4-recorded_images-171
#  → Tokens created: 2769
#
# Processing episode 172/199 — BreakoutNoFrameskip-v4-recorded_images-172
#  → Tokens created: 1989
#
# Processing episode 173/199 — BreakoutNoFrameskip-v4-recorded_images-173
#  → Tokens created: 3354
#
# Processing episode 174/199 — BreakoutNoFrameskip-v4-recorded_images-174
#  → Tokens created: 5031
#
# Processing episode 175/199 — BreakoutNoFrameskip-v4-recorded_images-175
#  → Tokens created: 897
#
# Processing episode 176/199 — BreakoutNoFrameskip-v4-recorded_images-176
#  → Tokens created: 7644
#
# Processing episode 177/199 — BreakoutNoFrameskip-v4-recorded_images-177
#  → Tokens created: 897
#
# Processing episode 178/199 — BreakoutNoFrameskip-v4-recorded_images-178
#  → Tokens created: 15366
#
# Processing episode 179/199 — BreakoutNoFrameskip-v4-recorded_images-179
#  → Tokens created: 8775
#
# Processing episode 180/199 — BreakoutNoFrameskip-v4-recorded_images-180
#  → Tokens created: 1989
#
# Processing episode 181/199 — BreakoutNoFrameskip-v4-recorded_images-181
#  → Tokens created: 3198
#
# Processing episode 182/199 — BreakoutNoFrameskip-v4-recorded_images-182
#  → Tokens created: 3276
#
# Processing episode 183/199 — BreakoutNoFrameskip-v4-recorded_images-183
#  → Tokens created: 2691
#
# Processing episode 184/199 — BreakoutNoFrameskip-v4-recorded_images-184
#  → Tokens created: 897
#
# Processing episode 185/199 — BreakoutNoFrameskip-v4-recorded_images-185
#  → Tokens created: 6708
#
# Processing episode 186/199 — BreakoutNoFrameskip-v4-recorded_images-186
#  → Tokens created: 897
#
# Processing episode 187/199 — BreakoutNoFrameskip-v4-recorded_images-187
#  → Tokens created: 1989
#
# Processing episode 188/199 — BreakoutNoFrameskip-v4-recorded_images-188
#  → Tokens created: 7098
#
# Processing episode 189/199 — BreakoutNoFrameskip-v4-recorded_images-189
#  → Tokens created: 897
#
# Processing episode 190/199 — BreakoutNoFrameskip-v4-recorded_images-190
#  → Tokens created: 6669
#
# Processing episode 191/199 — BreakoutNoFrameskip-v4-recorded_images-191
#  → Tokens created: 3354
#
# Processing episode 192/199 — BreakoutNoFrameskip-v4-recorded_images-192
#  → Tokens created: 6396
#
# Processing episode 193/199 — BreakoutNoFrameskip-v4-recorded_images-193
#  → Tokens created: 3354
#
# Processing episode 194/199 — BreakoutNoFrameskip-v4-recorded_images-194
#  → Tokens created: 897
#
# Processing episode 195/199 — BreakoutNoFrameskip-v4-recorded_images-195
#  → Tokens created: 3276
#
# Processing episode 196/199 — BreakoutNoFrameskip-v4-recorded_images-196
#  → Tokens created: 2769
#
# Processing episode 197/199 — BreakoutNoFrameskip-v4-recorded_images-197
#  → Tokens created: 2769
#
# Processing episode 198/199 — BreakoutNoFrameskip-v4-recorded_images-198
#  → Tokens created: 1989
#
# Processing episode 199/199 — BreakoutNoFrameskip-v4-recorded_images-199
#  → Tokens created: 2769
#
# ======== PREPROCESSING COMPLETE ========
# Saved token file → token_outputs/dataset_BreakoutNoFrameskip-v4_BreakoutNoFrameskip-v4_tokens.pkl
# =====================================================
#
# Found 200 NPZ sequences.
# Found 200 image folders.
#
# Processing episode 0/199 — EnduroNoFrameskip-v4-recorded_images-0
#  → Tokens created: 129558
#
# Processing episode 1/199 — EnduroNoFrameskip-v4-recorded_images-1
#  → Tokens created: 129441
#
# Processing episode 2/199 — EnduroNoFrameskip-v4-recorded_images-2
#  → Tokens created: 129519
#
# Processing episode 3/199 — EnduroNoFrameskip-v4-recorded_images-3
#  → Tokens created: 129519
#
# Processing episode 4/199 — EnduroNoFrameskip-v4-recorded_images-4
#  → Tokens created: 129441
#
# Processing episode 5/199 — EnduroNoFrameskip-v4-recorded_images-5
#  → Tokens created: 129480
#
# Processing episode 6/199 — EnduroNoFrameskip-v4-recorded_images-6
#  → Tokens created: 129714
#
# Processing episode 7/199 — EnduroNoFrameskip-v4-recorded_images-7
#  → Tokens created: 129480
#
# Processing episode 8/199 — EnduroNoFrameskip-v4-recorded_images-8
#  → Tokens created: 129480
#
# Processing episode 9/199 — EnduroNoFrameskip-v4-recorded_images-9
#  → Tokens created: 129519
#
# Processing episode 10/199 — EnduroNoFrameskip-v4-recorded_images-10
#  → Tokens created: 129441
#
# Processing episode 11/199 — EnduroNoFrameskip-v4-recorded_images-11
#  → Tokens created: 129558
#
# Processing episode 12/199 — EnduroNoFrameskip-v4-recorded_images-12
#  → Tokens created: 129480
#
# Processing episode 13/199 — EnduroNoFrameskip-v4-recorded_images-13
#  → Tokens created: 129480
#
# Processing episode 14/199 — EnduroNoFrameskip-v4-recorded_images-14
#  → Tokens created: 129480
#
# Processing episode 15/199 — EnduroNoFrameskip-v4-recorded_images-15
#  → Tokens created: 129558
#
# Processing episode 16/199 — EnduroNoFrameskip-v4-recorded_images-16
#  → Tokens created: 129480
#
# Processing episode 17/199 — EnduroNoFrameskip-v4-recorded_images-17
#  → Tokens created: 129558
#
# Processing episode 18/199 — EnduroNoFrameskip-v4-recorded_images-18
#  → Tokens created: 129519
#
# Processing episode 19/199 — EnduroNoFrameskip-v4-recorded_images-19
#  → Tokens created: 129558
#
# Processing episode 20/199 — EnduroNoFrameskip-v4-recorded_images-20
#  → Tokens created: 129597
#
# Processing episode 21/199 — EnduroNoFrameskip-v4-recorded_images-21
#  → Tokens created: 129519
#
# Processing episode 22/199 — EnduroNoFrameskip-v4-recorded_images-22
#  → Tokens created: 129441
#
# Processing episode 23/199 — EnduroNoFrameskip-v4-recorded_images-23
#  → Tokens created: 129636
#
# Processing episode 24/199 — EnduroNoFrameskip-v4-recorded_images-24
#  → Tokens created: 129519
#
# Processing episode 25/199 — EnduroNoFrameskip-v4-recorded_images-25
#  → Tokens created: 129480
#
# Processing episode 26/199 — EnduroNoFrameskip-v4-recorded_images-26
#  → Tokens created: 129480
#
# Processing episode 27/199 — EnduroNoFrameskip-v4-recorded_images-27
#  → Tokens created: 129675
#
# Processing episode 28/199 — EnduroNoFrameskip-v4-recorded_images-28
#  → Tokens created: 129441
#
# Processing episode 29/199 — EnduroNoFrameskip-v4-recorded_images-29
#  → Tokens created: 129519
#
# Processing episode 30/199 — EnduroNoFrameskip-v4-recorded_images-30
#  → Tokens created: 129714
#
# Processing episode 31/199 — EnduroNoFrameskip-v4-recorded_images-31
#  → Tokens created: 129675
#
# Processing episode 32/199 — EnduroNoFrameskip-v4-recorded_images-32
#  → Tokens created: 129519
#
# Processing episode 33/199 — EnduroNoFrameskip-v4-recorded_images-33
#  → Tokens created: 129558
#
# Processing episode 34/199 — EnduroNoFrameskip-v4-recorded_images-34
#  → Tokens created: 129441
#
# Processing episode 35/199 — EnduroNoFrameskip-v4-recorded_images-35
#  → Tokens created: 129441
#
# Processing episode 36/199 — EnduroNoFrameskip-v4-recorded_images-36
#  → Tokens created: 129519
#
# Processing episode 37/199 — EnduroNoFrameskip-v4-recorded_images-37
#  → Tokens created: 129480
#
# Processing episode 38/199 — EnduroNoFrameskip-v4-recorded_images-38
#  → Tokens created: 129519
#
# Processing episode 39/199 — EnduroNoFrameskip-v4-recorded_images-39
#  → Tokens created: 129636
#
# Processing episode 40/199 — EnduroNoFrameskip-v4-recorded_images-40
#  → Tokens created: 129441
#
# Processing episode 41/199 — EnduroNoFrameskip-v4-recorded_images-41
#  → Tokens created: 129441
#
# Processing episode 42/199 — EnduroNoFrameskip-v4-recorded_images-42
#  → Tokens created: 129597
#
# Processing episode 43/199 — EnduroNoFrameskip-v4-recorded_images-43
#  → Tokens created: 129675
#
# Processing episode 44/199 — EnduroNoFrameskip-v4-recorded_images-44
#  → Tokens created: 129558
#
# Processing episode 45/199 — EnduroNoFrameskip-v4-recorded_images-45
#  → Tokens created: 129519
#
# Processing episode 46/199 — EnduroNoFrameskip-v4-recorded_images-46
#  → Tokens created: 129480
#
# Processing episode 47/199 — EnduroNoFrameskip-v4-recorded_images-47
#  → Tokens created: 129597
#
# Processing episode 48/199 — EnduroNoFrameskip-v4-recorded_images-48
#  → Tokens created: 129519
#
# Processing episode 49/199 — EnduroNoFrameskip-v4-recorded_images-49
#  → Tokens created: 129636
#
# Processing episode 50/199 — EnduroNoFrameskip-v4-recorded_images-50
#  → Tokens created: 129519
#
# Processing episode 51/199 — EnduroNoFrameskip-v4-recorded_images-51
#  → Tokens created: 129636
#
# Processing episode 52/199 — EnduroNoFrameskip-v4-recorded_images-52
#  → Tokens created: 129597
#
# Processing episode 53/199 — EnduroNoFrameskip-v4-recorded_images-53
#  → Tokens created: 129441
#
# Processing episode 54/199 — EnduroNoFrameskip-v4-recorded_images-54
#  → Tokens created: 129519
#
# Processing episode 55/199 — EnduroNoFrameskip-v4-recorded_images-55
#  → Tokens created: 129636
#
# Processing episode 56/199 — EnduroNoFrameskip-v4-recorded_images-56
#  → Tokens created: 129441
#
# Processing episode 57/199 — EnduroNoFrameskip-v4-recorded_images-57
#  → Tokens created: 129597
#
# Processing episode 58/199 — EnduroNoFrameskip-v4-recorded_images-58
#  → Tokens created: 129519
#
# Processing episode 59/199 — EnduroNoFrameskip-v4-recorded_images-59
#  → Tokens created: 129675
#
# Processing episode 60/199 — EnduroNoFrameskip-v4-recorded_images-60
#  → Tokens created: 129519
#
# Processing episode 61/199 — EnduroNoFrameskip-v4-recorded_images-61
#  → Tokens created: 129480
#
# Processing episode 62/199 — EnduroNoFrameskip-v4-recorded_images-62
#  → Tokens created: 129675
#
# Processing episode 63/199 — EnduroNoFrameskip-v4-recorded_images-63
#  → Tokens created: 129597
#
# Processing episode 64/199 — EnduroNoFrameskip-v4-recorded_images-64
#  → Tokens created: 129519
#
# Processing episode 65/199 — EnduroNoFrameskip-v4-recorded_images-65
#  → Tokens created: 129636
#
# Processing episode 66/199 — EnduroNoFrameskip-v4-recorded_images-66
#  → Tokens created: 129558
#
# Processing episode 67/199 — EnduroNoFrameskip-v4-recorded_images-67
#  → Tokens created: 129480
#
# Processing episode 68/199 — EnduroNoFrameskip-v4-recorded_images-68
#  → Tokens created: 129480
#
# Processing episode 69/199 — EnduroNoFrameskip-v4-recorded_images-69
#  → Tokens created: 129441
#
# Processing episode 70/199 — EnduroNoFrameskip-v4-recorded_images-70
#  → Tokens created: 129441
#
# Processing episode 71/199 — EnduroNoFrameskip-v4-recorded_images-71
#  → Tokens created: 129636
#
# Processing episode 72/199 — EnduroNoFrameskip-v4-recorded_images-72
#  → Tokens created: 129519
#
# Processing episode 73/199 — EnduroNoFrameskip-v4-recorded_images-73
#  → Tokens created: 129480
#
# Processing episode 74/199 — EnduroNoFrameskip-v4-recorded_images-74
#  → Tokens created: 129558
#
# Processing episode 75/199 — EnduroNoFrameskip-v4-recorded_images-75
#  → Tokens created: 129558
#
# Processing episode 76/199 — EnduroNoFrameskip-v4-recorded_images-76
#  → Tokens created: 129558
#
# Processing episode 77/199 — EnduroNoFrameskip-v4-recorded_images-77
#  → Tokens created: 129519
#
# Processing episode 78/199 — EnduroNoFrameskip-v4-recorded_images-78
#  → Tokens created: 129480
#
# Processing episode 79/199 — EnduroNoFrameskip-v4-recorded_images-79
#  → Tokens created: 129480
#
# Processing episode 80/199 — EnduroNoFrameskip-v4-recorded_images-80
#  → Tokens created: 129597
#
# Processing episode 81/199 — EnduroNoFrameskip-v4-recorded_images-81
#  → Tokens created: 129558
#
# Processing episode 82/199 — EnduroNoFrameskip-v4-recorded_images-82
#  → Tokens created: 129441
#
# Processing episode 83/199 — EnduroNoFrameskip-v4-recorded_images-83
#  → Tokens created: 129597
#
# Processing episode 84/199 — EnduroNoFrameskip-v4-recorded_images-84
#  → Tokens created: 129558
#
# Processing episode 85/199 — EnduroNoFrameskip-v4-recorded_images-85
#  → Tokens created: 129519
#
# Processing episode 86/199 — EnduroNoFrameskip-v4-recorded_images-86
#  → Tokens created: 129441
#
# Processing episode 87/199 — EnduroNoFrameskip-v4-recorded_images-87
#  → Tokens created: 129480
#
# Processing episode 88/199 — EnduroNoFrameskip-v4-recorded_images-88
#  → Tokens created: 129558
#
# Processing episode 89/199 — EnduroNoFrameskip-v4-recorded_images-89
#  → Tokens created: 129558
#
# Processing episode 90/199 — EnduroNoFrameskip-v4-recorded_images-90
#  → Tokens created: 129597
#
# Processing episode 91/199 — EnduroNoFrameskip-v4-recorded_images-91
#  → Tokens created: 129519
#
# Processing episode 92/199 — EnduroNoFrameskip-v4-recorded_images-92
#  → Tokens created: 129480
#
# Processing episode 93/199 — EnduroNoFrameskip-v4-recorded_images-93
#  → Tokens created: 129441
#
# Processing episode 94/199 — EnduroNoFrameskip-v4-recorded_images-94
#  → Tokens created: 129558
#
# Processing episode 95/199 — EnduroNoFrameskip-v4-recorded_images-95
#  → Tokens created: 129636
#
# Processing episode 96/199 — EnduroNoFrameskip-v4-recorded_images-96
#  → Tokens created: 129441
#
# Processing episode 97/199 — EnduroNoFrameskip-v4-recorded_images-97
#  → Tokens created: 129636
#
# Processing episode 98/199 — EnduroNoFrameskip-v4-recorded_images-98
#  → Tokens created: 129480
#
# Processing episode 99/199 — EnduroNoFrameskip-v4-recorded_images-99
#  → Tokens created: 129558
#
# Processing episode 100/199 — EnduroNoFrameskip-v4-recorded_images-100
#  → Tokens created: 129597
#
# Processing episode 101/199 — EnduroNoFrameskip-v4-recorded_images-101
#  → Tokens created: 129441
#
# Processing episode 102/199 — EnduroNoFrameskip-v4-recorded_images-102
#  → Tokens created: 129636
#
# Processing episode 103/199 — EnduroNoFrameskip-v4-recorded_images-103
#  → Tokens created: 129519
#
# Processing episode 104/199 — EnduroNoFrameskip-v4-recorded_images-104
#  → Tokens created: 129519
#
# Processing episode 105/199 — EnduroNoFrameskip-v4-recorded_images-105
#  → Tokens created: 129519
#
# Processing episode 106/199 — EnduroNoFrameskip-v4-recorded_images-106
#  → Tokens created: 129441
#
# Processing episode 107/199 — EnduroNoFrameskip-v4-recorded_images-107
#  → Tokens created: 129558
#
# Processing episode 108/199 — EnduroNoFrameskip-v4-recorded_images-108
#  → Tokens created: 129519
#
# Processing episode 109/199 — EnduroNoFrameskip-v4-recorded_images-109
#  → Tokens created: 129597
#
# Processing episode 110/199 — EnduroNoFrameskip-v4-recorded_images-110
#  → Tokens created: 129480
#
# Processing episode 111/199 — EnduroNoFrameskip-v4-recorded_images-111
#  → Tokens created: 129675
#
# Processing episode 112/199 — EnduroNoFrameskip-v4-recorded_images-112
#  → Tokens created: 129597
#
# Processing episode 113/199 — EnduroNoFrameskip-v4-recorded_images-113
#  → Tokens created: 129441
#
# Processing episode 114/199 — EnduroNoFrameskip-v4-recorded_images-114
#  → Tokens created: 129558
#
# Processing episode 115/199 — EnduroNoFrameskip-v4-recorded_images-115
#  → Tokens created: 129675
#
# Processing episode 116/199 — EnduroNoFrameskip-v4-recorded_images-116
#  → Tokens created: 129636
#
# Processing episode 117/199 — EnduroNoFrameskip-v4-recorded_images-117
#  → Tokens created: 129441
#
# Processing episode 118/199 — EnduroNoFrameskip-v4-recorded_images-118
#  → Tokens created: 129519
#
# Processing episode 119/199 — EnduroNoFrameskip-v4-recorded_images-119
#  → Tokens created: 129480
#
# Processing episode 120/199 — EnduroNoFrameskip-v4-recorded_images-120
#  → Tokens created: 129519
#
# Processing episode 121/199 — EnduroNoFrameskip-v4-recorded_images-121
#  → Tokens created: 129597
#
# Processing episode 122/199 — EnduroNoFrameskip-v4-recorded_images-122
#  → Tokens created: 129480
#
# Processing episode 123/199 — EnduroNoFrameskip-v4-recorded_images-123
#  → Tokens created: 129441
#
# Processing episode 124/199 — EnduroNoFrameskip-v4-recorded_images-124
#  → Tokens created: 129480
#
# Processing episode 125/199 — EnduroNoFrameskip-v4-recorded_images-125
#  → Tokens created: 129519
#
# Processing episode 126/199 — EnduroNoFrameskip-v4-recorded_images-126
#  → Tokens created: 129441
#
# Processing episode 127/199 — EnduroNoFrameskip-v4-recorded_images-127
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 41
#      38 img_folder = image_folders[idx]
#      39 print(f"\nProcessing episode {idx}/{len(npz_sequences)-1} — {img_folder.name}")
# ---> 41 tokens = preprocess_one_sequence(
#      42     npz_seq=npz_seq,
#      43     game_root=game_root,
#      44     seq_index=idx
#      45 )
#      47 print(f" → Tokens created: {len(tokens)}")
#      48 all_token_lists.append(tokens)
#
# File ~/Downloads/AtariDeepLearning-main/atari_preprocess.py:189, in preprocess_one_sequence(npz_seq, game_root, seq_index)
#     187 # ---- Load frames (sorted by name) ----
#     188 image_paths = sorted(image_folder.glob("*"))
# --> 189 frames = np.stack([
#     190     load_frame(image_folder, p.name) for p in image_paths
#     191 ])
#     193 num_frames = frames.shape[0]
#     194 num_steps = len(actions)
#
# File ~/Downloads/AtariDeepLearning-main/atari_preprocess.py:190, in <listcomp>(.0)
#     187 # ---- Load frames (sorted by name) ----
#     188 image_paths = sorted(image_folder.glob("*"))
#     189 frames = np.stack([
# --> 190     load_frame(image_folder, p.name) for p in image_paths
#     191 ])
#     193 num_frames = frames.shape[0]
#     194 num_steps = len(actions)
#
# File ~/Downloads/AtariDeepLearning-main/atari_preprocess.py:73, in load_frame(dataset_root, rel_path)
#      70 if not full_path.exists():
#      71     raise FileNotFoundError(f"Image not found: {full_path}")
# ---> 73 img = cv2.imread(str(full_path))
#      74 img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#      75 img = cv2.resize(img, (84, 84))
#
# KeyboardInterrupt:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
